# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm  # Import tqdm for progress tracking


class TrajectoryDataset(Dataset):
    def __init__(self, dataframe, window_length=100):
        # Perform the custom transformation
        sliced_df = self.custom_transformation(dataframe.to_numpy(), window_length=window_length)
        self.data = torch.tensor(sliced_df, dtype=torch.float32)

    def __len__(self):
        # Return the number of trajectories
        return self.data.shape[0]

    def __getitem__(self, idx):
        # Get the trajectory at the given index
        return self.data[idx]

    def custom_transformation(self, dataframe_array, window_length):
        num_rows, num_cols = dataframe_array.shape
        window_length += 1  # get one more column as targets

        # Preallocate memory for the slices
        sliced_data = np.lib.stride_tricks.sliding_window_view(dataframe_array, window_shape=(window_length,), axis=1)
        
        # Reshape into a flat 2D array for DataFrame-like output
        sliced_data = sliced_data.reshape(-1, window_length)

        return sliced_data
    
class CNNModel(nn.Module):
    def __init__(self, input_size, output_size, num_filters=64, kernel_size=2, dropout_rate=0.3):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=num_filters, kernel_size=kernel_size)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool1d(kernel_size=2)
        self.dropout = nn.Dropout(dropout_rate)
        # self.bn1 = nn.BatchNorm1d(num_features=num_filters)  # BatchNorm after Conv1d

        # Calculate flattened size for the fully connected layer
        conv_output_size = (input_size - kernel_size + 1) // 2  # After pooling

        # Fully connected layer
        self.fc = nn.Linear(num_filters * conv_output_size, output_size)

    def forward(self, x):
        x = nn.functional.normalize(x)
        x = x.unsqueeze(1)  # Add a channel dimension for CNN
        x = self.conv1(x)
        # x = self.bn1(x)  # Apply BatchNorm
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        # Flatten the output for the fully connected layer
        x = x.view(x.size(0), -1)
        out = self.fc(x)  #Try fc2
        return out

# %% [markdown]
# ## Training loop

# %%
import os

# Get the relative path of a file in the current working directory
train_path = os.path.join('train.csv')
val_path = os.path.join('val.csv')
test_path = os.path.join('test.csv')

train_df = pd.read_csv(train_path, header = 0).drop('ids', axis=1)
val_df = pd.read_csv(val_path, header = 0).drop('ids', axis=1)
test_df = pd.read_csv(test_path, header = 0).drop('ids', axis=1)

# %%
from torch.nn import init # Import init from torch.nn.init
from torch.optim.lr_scheduler import ReduceLROnPlateau

# Check if MPS is available and set the device accordingly
device = torch.device('cpu')
if torch.cuda.is_available():
    device = torch.device("cuda")

window_length = 100  # Example window length
dataset = TrajectoryDataset(dataframe=train_df, window_length=window_length)
batch_size = 32
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# Model hyperparameters
input_size = window_length  # Window length minus 1 (since the last column is the target)
output_size = 1  # Single output for time series forecast (next value)
learning_rate = 0.001
num_epochs = 1
dropout_rate = 0.3

# Instantiate the model, loss function, and optimizer
model = CNNModel(input_size, output_size, num_filters=64, kernel_size=2, dropout_rate=dropout_rate).to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-3) 
scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=10, factor=0.1, verbose=True)

# Training loop with tqdm for progress tracking
for epoch in tqdm(range(num_epochs), desc="Epochs", unit="epoch"):
    model.train()
    running_loss = 0.0
    # Use tqdm to track batch progress within each epoch
    for batch_idx, data in tqdm(enumerate(dataloader), desc=f"Epoch {epoch + 1}", unit="batch", leave=False):
        # Separate inputs and targets
        inputs = data[:, :-1].to(device)  # All except last column
        targets = data[:, -1].to(device)  # Last column is the target (next value)
        
        # Zero the parameter gradients
        optimizer.zero_grad() 
        
        # Forward pass
        outputs = model(inputs)
        
        # Compute the loss
        loss = criterion(outputs.squeeze(), targets)
        
        # Backward pass and optimize
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.3)  # Adjust max_norm as needed
        optimizer.step()

        # Check for NaN or Infinite Values in the loss
        if torch.isnan(loss) or torch.isinf(loss):
            print("Loss is NaN or Inf. Stopping training.")
            break  

        running_loss += loss.item()

    avg_train_loss = running_loss / len(dataloader)
    
    # Print the average loss per epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {running_loss / len(dataloader):.4f}')
# Out:
# C:\Users\simra\anaconda3\Lib\site-packages\torch\optim\lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epochs:   0%|                                                                                 | 0/1 [00:00<?, ?epoch/s]
# Epoch 1: 0batch [00:00, ?batch/s]
# Epoch 1: 1batch [00:00,  1.76batch/s]
# Epoch 1: 28batch [00:00, 55.27batch/s]
# Epoch 1: 44batch [00:00, 74.95batch/s]
# Epoch 1: 69batch [00:00, 115.52batch/s]
# Epoch 1: 94batch [00:00, 147.90batch/s]
# Epoch 1: 122batch [00:01, 181.60batch/s]
# Epoch 1: 149batch [00:01, 204.16batch/s]
# Epoch 1: 176batch [00:01, 220.64batch/s]
# Epoch 1: 203batch [00:01, 233.49batch/s]
# Epoch 1: 230batch [00:01, 242.31batch/s]
# Epoch 1: 260batch [00:01, 257.50batch/s]
# Epoch 1: 287batch [00:01, 251.62batch/s]
# Epoch 1: 313batch [00:01, 232.55batch/s]
# Epoch 1: 338batch [00:01, 215.61batch/s]
# Epoch 1: 361batch [00:02, 218.23batch/s]
# Epoch 1: 384batch [00:02, 218.65batch/s]
# Epoch 1: 409batch [00:02, 227.31batch/s]
# Epoch 1: 434batch [00:02, 232.42batch/s]
# Epoch 1: 458batch [00:02, 226.79batch/s]
# Epoch 1: 483batch [00:02, 232.71batch/s]
# Epoch 1: 507batch [00:02, 234.14batch/s]
# Epoch 1: 531batch [00:02, 233.69batch/s]
# Epoch 1: 555batch [00:02, 235.49batch/s]
# Epoch 1: 579batch [00:03, 232.76batch/s]
# Epoch 1: 603batch [00:03, 232.57batch/s]
# Epoch 1: 633batch [00:03, 252.29batch/s]
# Epoch 1: 662batch [00:03, 263.40batch/s]
# Epoch 1: 691batch [00:03, 271.16batch/s]
# Epoch 1: 720batch [00:03, 275.13batch/s]
# Epoch 1: 748batch [00:03, 274.61batch/s]
# Epoch 1: 776batch [00:03, 273.71batch/s]
# Epoch 1: 804batch [00:03, 272.34batch/s]
# Epoch 1: 832batch [00:03, 270.57batch/s]
# Epoch 1: 861batch [00:04, 273.50batch/s]
# Epoch 1: 889batch [00:04, 246.67batch/s]
# Epoch 1: 915batch [00:04, 248.27batch/s]
# Epoch 1: 944batch [00:04, 259.18batch/s]
# Epoch 1: 974batch [00:04, 268.94batch/s]
# Epoch 1: 1004batch [00:04, 277.82batch/s]
# Epoch 1: 1036batch [00:04, 288.41batch/s]
# Epoch 1: 1067batch [00:04, 293.87batch/s]
# Epoch 1: 1098batch [00:04, 296.00batch/s]
# Epoch 1: 1128batch [00:05, 288.46batch/s]
# Epoch 1: 1160batch [00:05, 295.99batch/s]
# Epoch 1: 1194batch [00:05, 306.15batch/s]
# Epoch 1: 1225batch [00:05, 305.49batch/s]
# Epoch 1: 1256batch [00:05, 298.32batch/s]
# Epoch 1: 1286batch [00:05, 294.55batch/s]
# Epoch 1: 1316batch [00:05, 291.07batch/s]
# Epoch 1: 1346batch [00:05, 288.56batch/s]
# Epoch 1: 1377batch [00:05, 292.48batch/s]
# Epoch 1: 1407batch [00:05, 279.42batch/s]
# Epoch 1: 1436batch [00:06, 281.61batch/s]
# Epoch 1: 1466batch [00:06, 285.66batch/s]
# Epoch 1: 1496batch [00:06, 289.68batch/s]
# Epoch 1: 1527batch [00:06, 293.83batch/s]
# Epoch 1: 1558batch [00:06, 297.70batch/s]
# Epoch 1: 1590batch [00:06, 301.61batch/s]
# Epoch 1: 1627batch [00:06, 319.87batch/s]
# Epoch 1: 1660batch [00:06, 313.81batch/s]
# Epoch 1: 1692batch [00:06, 304.23batch/s]
# Epoch 1: 1723batch [00:07, 305.12batch/s]
# Epoch 1: 1754batch [00:07, 303.03batch/s]
# Epoch 1: 1786batch [00:07, 305.55batch/s]
# Epoch 1: 1817batch [00:07, 306.67batch/s]
# Epoch 1: 1848batch [00:07, 302.90batch/s]
# Epoch 1: 1879batch [00:07, 304.54batch/s]
# Epoch 1: 1912batch [00:07, 310.20batch/s]
# Epoch 1: 1944batch [00:07, 308.94batch/s]
# Epoch 1: 1976batch [00:07, 310.22batch/s]
# Epoch 1: 2008batch [00:07, 310.36batch/s]
# Epoch 1: 2040batch [00:08, 305.12batch/s]
# Epoch 1: 2071batch [00:08, 305.19batch/s]
# Epoch 1: 2102batch [00:08, 304.43batch/s]
# Epoch 1: 2133batch [00:08, 303.88batch/s]
# Epoch 1: 2164batch [00:08, 302.46batch/s]
# Epoch 1: 2195batch [00:08, 298.22batch/s]
# Epoch 1: 2228batch [00:08, 305.44batch/s]
# Epoch 1: 2259batch [00:08, 302.35batch/s]
# Epoch 1: 2290batch [00:08, 300.10batch/s]
# Epoch 1: 2321batch [00:08, 301.11batch/s]
# Epoch 1: 2354batch [00:09, 308.66batch/s]
# Epoch 1: 2386batch [00:09, 310.69batch/s]
# Epoch 1: 2420batch [00:09, 318.26batch/s]
# Epoch 1: 2453batch [00:09, 319.84batch/s]
# Epoch 1: 2485batch [00:09, 318.00batch/s]
# Epoch 1: 2517batch [00:09, 316.69batch/s]
# Epoch 1: 2550batch [00:09, 318.55batch/s]
# Epoch 1: 2583batch [00:09, 320.99batch/s]
# Epoch 1: 2616batch [00:09, 315.25batch/s]
# Epoch 1: 2648batch [00:09, 310.29batch/s]
# Epoch 1: 2683batch [00:10, 319.96batch/s]
# Epoch 1: 2717batch [00:10, 323.92batch/s]
# Epoch 1: 2751batch [00:10, 327.67batch/s]
# Epoch 1: 2786batch [00:10, 332.29batch/s]
# Epoch 1: 2820batch [00:10, 322.35batch/s]
# Epoch 1: 2853batch [00:10, 308.24batch/s]
# Epoch 1: 2884batch [00:10, 301.77batch/s]
# Epoch 1: 2915batch [00:10, 298.67batch/s]
# Epoch 1: 2945batch [00:10, 292.41batch/s]
# Epoch 1: 2975batch [00:11, 287.85batch/s]
# Epoch 1: 3004batch [00:11, 288.31batch/s]
# Epoch 1: 3033batch [00:11, 288.44batch/s]
# Epoch 1: 3063batch [00:11, 289.88batch/s]
# Epoch 1: 3093batch [00:11, 249.59batch/s]
# Epoch 1: 3122batch [00:11, 257.84batch/s]
# Epoch 1: 3151batch [00:11, 265.37batch/s]
# Epoch 1: 3181batch [00:11, 274.37batch/s]
# Epoch 1: 3211batch [00:11, 281.06batch/s]
# Epoch 1: 3240batch [00:12, 281.08batch/s]
# Epoch 1: 3269batch [00:12, 282.17batch/s]
# Epoch 1: 3300batch [00:12, 288.26batch/s]
# Epoch 1: 3330batch [00:12, 290.00batch/s]
# Epoch 1: 3361batch [00:12, 295.17batch/s]
# Epoch 1: 3393batch [00:12, 301.60batch/s]
# Epoch 1: 3425batch [00:12, 307.04batch/s]
# Epoch 1: 3458batch [00:12, 313.86batch/s]
# Epoch 1: 3490batch [00:12, 309.69batch/s]
# Epoch 1: 3522batch [00:12, 309.08batch/s]
# Epoch 1: 3553batch [00:13, 303.29batch/s]
# Epoch 1: 3584batch [00:13, 304.75batch/s]
# Epoch 1: 3615batch [00:13, 305.53batch/s]
# Epoch 1: 3647batch [00:13, 306.19batch/s]
# Epoch 1: 3678batch [00:13, 304.87batch/s]
# Epoch 1: 3709batch [00:13, 301.74batch/s]
# Epoch 1: 3742batch [00:13, 307.31batch/s]
# Epoch 1: 3777batch [00:13, 316.12batch/s]
# Epoch 1: 3809batch [00:13, 316.24batch/s]
# Epoch 1: 3841batch [00:13, 312.83batch/s]
# Epoch 1: 3876batch [00:14, 323.00batch/s]
# Epoch 1: 3909batch [00:14, 319.41batch/s]
# Epoch 1: 3945batch [00:14, 330.07batch/s]
# Epoch 1: 3979batch [00:14, 328.16batch/s]
# Epoch 1: 4013batch [00:14, 329.63batch/s]
# Epoch 1: 4046batch [00:14, 323.06batch/s]
# Epoch 1: 4079batch [00:14, 320.93batch/s]
# Epoch 1: 4112batch [00:14, 317.57batch/s]
# Epoch 1: 4144batch [00:14, 314.63batch/s]
# Epoch 1: 4176batch [00:15, 304.63batch/s]
# Epoch 1: 4208batch [00:15, 306.55batch/s]
# Epoch 1: 4240batch [00:15, 309.85batch/s]
# Epoch 1: 4272batch [00:15, 309.36batch/s]
# Epoch 1: 4304batch [00:15, 311.51batch/s]
# Epoch 1: 4336batch [00:15, 314.00batch/s]
# Epoch 1: 4370batch [00:15, 320.28batch/s]
# Epoch 1: 4403batch [00:15, 320.63batch/s]
# Epoch 1: 4436batch [00:15, 316.65batch/s]
# Epoch 1: 4468batch [00:15, 316.21batch/s]
# Epoch 1: 4500batch [00:16, 315.32batch/s]
# Epoch 1: 4533batch [00:16, 317.20batch/s]
# Epoch 1: 4566batch [00:16, 318.16batch/s]
# Epoch 1: 4602batch [00:16, 329.50batch/s]
# Epoch 1: 4635batch [00:16, 329.65batch/s]
# Epoch 1: 4668batch [00:16, 327.74batch/s]
# Epoch 1: 4702batch [00:16, 331.37batch/s]
# Epoch 1: 4736batch [00:16, 325.54batch/s]
# Epoch 1: 4769batch [00:16, 323.46batch/s]
# Epoch 1: 4802batch [00:16, 318.17batch/s]
# Epoch 1: 4834batch [00:17, 305.30batch/s]
# Epoch 1: 4867batch [00:17, 311.58batch/s]
# Epoch 1: 4899batch [00:17, 309.34batch/s]
# Epoch 1: 4931batch [00:17, 310.02batch/s]
# Epoch 1: 4963batch [00:17, 305.39batch/s]
# Epoch 1: 4994batch [00:17, 300.99batch/s]
# Epoch 1: 5026batch [00:17, 305.61batch/s]
# Epoch 1: 5058batch [00:17, 303.60batch/s]
# Epoch 1: 5090batch [00:17, 305.76batch/s]
# Epoch 1: 5123batch [00:18, 311.90batch/s]
# Epoch 1: 5156batch [00:18, 304.90batch/s]
# Epoch 1: 5187batch [00:18, 273.86batch/s]
# Epoch 1: 5219batch [00:18, 284.70batch/s]
# Epoch 1: 5249batch [00:18, 288.50batch/s]
# Epoch 1: 5282batch [00:18, 297.66batch/s]
# Epoch 1: 5313batch [00:18, 299.37batch/s]
# Epoch 1: 5346batch [00:18, 305.66batch/s]
# Epoch 1: 5380batch [00:18, 315.58batch/s]
# Epoch 1: 5414batch [00:19, 321.03batch/s]
# Epoch 1: 5447batch [00:19, 319.28batch/s]
# Epoch 1: 5481batch [00:19, 322.52batch/s]
# Epoch 1: 5514batch [00:19, 316.23batch/s]
# Epoch 1: 5546batch [00:19, 311.88batch/s]
# Epoch 1: 5578batch [00:19, 313.03batch/s]
# Epoch 1: 5612batch [00:19, 318.11batch/s]
# Epoch 1: 5644batch [00:19, 315.44batch/s]
# Epoch 1: 5676batch [00:19, 312.69batch/s]
# Epoch 1: 5708batch [00:19, 312.10batch/s]
# Epoch 1: 5740batch [00:20, 312.58batch/s]
# Epoch 1: 5772batch [00:20, 313.84batch/s]
# Epoch 1: 5804batch [00:20, 314.40batch/s]
# Epoch 1: 5836batch [00:20, 313.92batch/s]
# Epoch 1: 5869batch [00:20, 317.74batch/s]
# Epoch 1: 5901batch [00:20, 312.92batch/s]
# Epoch 1: 5933batch [00:20, 311.55batch/s]
# Epoch 1: 5966batch [00:20, 316.03batch/s]
# Epoch 1: 5998batch [00:20, 311.47batch/s]
# Epoch 1: 6032batch [00:20, 317.95batch/s]
# Epoch 1: 6067batch [00:21, 326.41batch/s]
# Epoch 1: 6101batch [00:21, 327.52batch/s]
# Epoch 1: 6139batch [00:21, 339.97batch/s]
# Epoch 1: 6174batch [00:21, 339.92batch/s]
# Epoch 1: 6208batch [00:21, 336.97batch/s]
# Epoch 1: 6242batch [00:21, 331.81batch/s]
# Epoch 1: 6276batch [00:21, 332.26batch/s]
# Epoch 1: 6311batch [00:21, 335.50batch/s]
# Epoch 1: 6346batch [00:21, 338.77batch/s]
# Epoch 1: 6380batch [00:22, 333.22batch/s]
# Epoch 1: 6414batch [00:22, 328.99batch/s]
# Epoch 1: 6449batch [00:22, 335.09batch/s]
# Epoch 1: 6483batch [00:22, 331.66batch/s]
# Epoch 1: 6517batch [00:22, 331.19batch/s]
# Epoch 1: 6551batch [00:22, 328.01batch/s]
# Epoch 1: 6586batch [00:22, 332.47batch/s]
# Epoch 1: 6620batch [00:22, 327.62batch/s]
# Epoch 1: 6653batch [00:22, 325.23batch/s]
# Epoch 1: 6688batch [00:22, 331.45batch/s]
# Epoch 1: 6722batch [00:23, 331.10batch/s]
# Epoch 1: 6756batch [00:23, 333.45batch/s]
# Epoch 1: 6790batch [00:23, 329.55batch/s]
# Epoch 1: 6823batch [00:23, 326.80batch/s]
# Epoch 1: 6856batch [00:23, 323.01batch/s]
# Epoch 1: 6889batch [00:23, 323.12batch/s]
# Epoch 1: 6924batch [00:23, 325.71batch/s]
# Epoch 1: 6957batch [00:23, 299.36batch/s]
# Epoch 1: 6992batch [00:23, 310.77batch/s]
# Epoch 1: 7027batch [00:23, 320.01batch/s]
# Epoch 1: 7060batch [00:24, 321.94batch/s]
# Epoch 1: 7093batch [00:24, 322.41batch/s]
# Epoch 1: 7126batch [00:24, 323.68batch/s]
# Epoch 1: 7159batch [00:24, 322.69batch/s]
# Epoch 1: 7192batch [00:24, 322.94batch/s]
# Epoch 1: 7227batch [00:24, 329.93batch/s]
# Epoch 1: 7261batch [00:24, 330.07batch/s]
# Epoch 1: 7295batch [00:24, 327.22batch/s]
# Epoch 1: 7329batch [00:24, 329.99batch/s]
# Epoch 1: 7364batch [00:25, 333.63batch/s]
# Epoch 1: 7398batch [00:25, 334.07batch/s]
# Epoch 1: 7432batch [00:25, 334.37batch/s]
# Epoch 1: 7466batch [00:25, 329.76batch/s]
# Epoch 1: 7501batch [00:25, 332.76batch/s]
# Epoch 1: 7535batch [00:25, 331.62batch/s]
# Epoch 1: 7569batch [00:25, 331.17batch/s]
# Epoch 1: 7603batch [00:25, 333.75batch/s]
# Epoch 1: 7637batch [00:25, 330.54batch/s]
# Epoch 1: 7671batch [00:25, 327.13batch/s]
# Epoch 1: 7704batch [00:26, 324.43batch/s]
# Epoch 1: 7737batch [00:26, 324.61batch/s]
# Epoch 1: 7771batch [00:26, 327.21batch/s]
# Epoch 1: 7806batch [00:26, 333.13batch/s]
# Epoch 1: 7840batch [00:26, 333.19batch/s]
# Epoch 1: 7874batch [00:26, 333.23batch/s]
# Epoch 1: 7908batch [00:26, 333.05batch/s]
# Epoch 1: 7945batch [00:26, 342.16batch/s]
# Epoch 1: 7980batch [00:26, 338.25batch/s]
# Epoch 1: 8014batch [00:26, 331.96batch/s]
# Epoch 1: 8048batch [00:27, 333.33batch/s]
# Epoch 1: 8082batch [00:27, 331.39batch/s]
# Epoch 1: 8116batch [00:27, 330.57batch/s]
# Epoch 1: 8150batch [00:27, 332.74batch/s]
# Epoch 1: 8184batch [00:27, 332.14batch/s]
# Epoch 1: 8221batch [00:27, 340.82batch/s]
# Epoch 1: 8256batch [00:27, 335.16batch/s]
# Epoch 1: 8290batch [00:27, 324.29batch/s]
# Epoch 1: 8323batch [00:27, 324.07batch/s]
# Epoch 1: 8356batch [00:28, 307.15batch/s]
# Epoch 1: 8387batch [00:28, 302.85batch/s]
# Epoch 1: 8420batch [00:28, 309.59batch/s]
# Epoch 1: 8452batch [00:28, 311.67batch/s]
# Epoch 1: 8486batch [00:28, 316.22batch/s]
# Epoch 1: 8520batch [00:28, 323.13batch/s]
# Epoch 1: 8553batch [00:28, 292.60batch/s]
# Epoch 1: 8586batch [00:28, 302.84batch/s]
# Epoch 1: 8621batch [00:28, 313.46batch/s]
# Epoch 1: 8655batch [00:28, 320.11batch/s]
# Epoch 1: 8690batch [00:29, 327.79batch/s]
# Epoch 1: 8724batch [00:29, 330.39batch/s]
# Epoch 1: 8758batch [00:29, 325.57batch/s]
# Epoch 1: 8793batch [00:29, 330.74batch/s]
# Epoch 1: 8828batch [00:29, 332.48batch/s]
# Epoch 1: 8862batch [00:29, 333.70batch/s]
# Epoch 1: 8896batch [00:29, 329.74batch/s]
# Epoch 1: 8932batch [00:29, 336.69batch/s]
# Epoch 1: 8966batch [00:29, 335.69batch/s]
# Epoch 1: 9000batch [00:30, 331.12batch/s]
# Epoch 1: 9034batch [00:30, 331.77batch/s]
# Epoch 1: 9068batch [00:30, 327.32batch/s]
# Epoch 1: 9102batch [00:30, 329.16batch/s]
# Epoch 1: 9135batch [00:30, 328.99batch/s]
# Epoch 1: 9169batch [00:30, 331.80batch/s]
# Epoch 1: 9203batch [00:30, 333.24batch/s]
# Epoch 1: 9237batch [00:30, 333.81batch/s]
# Epoch 1: 9271batch [00:30, 332.18batch/s]
# Epoch 1: 9305batch [00:30, 328.58batch/s]
# Epoch 1: 9338batch [00:31, 326.13batch/s]
# Epoch 1: 9373batch [00:31, 329.85batch/s]
# Epoch 1: 9406batch [00:31, 326.65batch/s]
# Epoch 1: 9440batch [00:31, 327.79batch/s]
# Epoch 1: 9476batch [00:31, 334.31batch/s]
# Epoch 1: 9512batch [00:31, 339.85batch/s]
# Epoch 1: 9549batch [00:31, 347.70batch/s]
# Epoch 1: 9584batch [00:31, 346.33batch/s]
# Epoch 1: 9619batch [00:31, 340.38batch/s]
# Epoch 1: 9654batch [00:31, 338.51batch/s]
# Epoch 1: 9688batch [00:32, 335.03batch/s]
# Epoch 1: 9723batch [00:32, 336.45batch/s]
# Epoch 1: 9757batch [00:32, 334.49batch/s]
# Epoch 1: 9793batch [00:32, 340.96batch/s]
# Epoch 1: 9828batch [00:32, 338.63batch/s]
# Epoch 1: 9863batch [00:32, 341.87batch/s]
# Epoch 1: 9898batch [00:32, 338.28batch/s]
# Epoch 1: 9932batch [00:32, 334.09batch/s]
# Epoch 1: 9966batch [00:32, 312.95batch/s]
# Epoch 1: 9998batch [00:33, 296.83batch/s]
# Epoch 1: 10032batch [00:33, 307.70batch/s]
# Epoch 1: 10065batch [00:33, 313.70batch/s]
# Epoch 1: 10097batch [00:33, 314.60batch/s]
# Epoch 1: 10131batch [00:33, 321.02batch/s]
# Epoch 1: 10164batch [00:33, 322.39batch/s]
# Epoch 1: 10201batch [00:33, 333.43batch/s]
# Epoch 1: 10235batch [00:33, 335.14batch/s]
# Epoch 1: 10269batch [00:33, 328.76batch/s]
# Epoch 1: 10303batch [00:33, 330.11batch/s]
# Epoch 1: 10337batch [00:34, 331.25batch/s]
# Epoch 1: 10371batch [00:34, 331.87batch/s]
# Epoch 1: 10405batch [00:34, 330.38batch/s]
# Epoch 1: 10439batch [00:34, 333.13batch/s]
# Epoch 1: 10474batch [00:34, 335.15batch/s]
# Epoch 1: 10508batch [00:34, 336.58batch/s]
# Epoch 1: 10542batch [00:34, 335.24batch/s]
# Epoch 1: 10576batch [00:34, 333.69batch/s]
# Epoch 1: 10612batch [00:34, 338.46batch/s]
# Epoch 1: 10647batch [00:34, 339.78batch/s]
# Epoch 1: 10681batch [00:35, 335.67batch/s]
# Epoch 1: 10716batch [00:35, 335.94batch/s]
# Epoch 1: 10751batch [00:35, 336.12batch/s]
# Epoch 1: 10787batch [00:35, 343.11batch/s]
# Epoch 1: 10822batch [00:35, 337.26batch/s]
# Epoch 1: 10856batch [00:35, 330.26batch/s]
# Epoch 1: 10890batch [00:35, 330.73batch/s]
# Epoch 1: 10925batch [00:35, 336.34batch/s]
# Epoch 1: 10959batch [00:35, 329.67batch/s]
# Epoch 1: 10993batch [00:36, 327.91batch/s]
# Epoch 1: 11027batch [00:36, 329.51batch/s]
# Epoch 1: 11062batch [00:36, 333.54batch/s]
# Epoch 1: 11097batch [00:36, 337.38batch/s]
# Epoch 1: 11131batch [00:36, 334.21batch/s]
# Epoch 1: 11166batch [00:36, 336.87batch/s]
# Epoch 1: 11200batch [00:36, 333.61batch/s]
# Epoch 1: 11234batch [00:36, 328.73batch/s]
# Epoch 1: 11267batch [00:36, 308.44batch/s]
# Epoch 1: 11299batch [00:37, 297.10batch/s]
# Epoch 1: 11334batch [00:37, 310.86batch/s]
# Epoch 1: 11366batch [00:37, 312.56batch/s]
# Epoch 1: 11403batch [00:37, 327.17batch/s]
# Epoch 1: 11438batch [00:37, 333.54batch/s]
# Epoch 1: 11472batch [00:37, 328.60batch/s]
# Epoch 1: 11506batch [00:37, 330.94batch/s]
# Epoch 1: 11540batch [00:37, 329.59batch/s]
# Epoch 1: 11574batch [00:37, 327.84batch/s]
# Epoch 1: 11607batch [00:37, 324.96batch/s]
# Epoch 1: 11644batch [00:38, 336.10batch/s]
# Epoch 1: 11678batch [00:38, 336.26batch/s]
# Epoch 1: 11714batch [00:38, 341.24batch/s]
# Epoch 1: 11749batch [00:38, 339.81batch/s]
# Epoch 1: 11783batch [00:38, 336.90batch/s]
# Epoch 1: 11818batch [00:38, 338.33batch/s]
# Epoch 1: 11852batch [00:38, 336.84batch/s]
# Epoch 1: 11886batch [00:38, 337.68batch/s]
# Epoch 1: 11920batch [00:38, 331.49batch/s]
# Epoch 1: 11955batch [00:38, 335.30batch/s]
# Epoch 1: 11992batch [00:39, 342.49batch/s]
# Epoch 1: 12030batch [00:39, 352.48batch/s]
# Epoch 1: 12066batch [00:39, 344.53batch/s]
# Epoch 1: 12101batch [00:39, 345.68batch/s]
# Epoch 1: 12136batch [00:39, 342.93batch/s]
# Epoch 1: 12172batch [00:39, 344.39batch/s]
# Epoch 1: 12207batch [00:39, 342.03batch/s]
# Epoch 1: 12242batch [00:39, 338.41batch/s]
# Epoch 1: 12277batch [00:39, 340.79batch/s]
# Epoch 1: 12312batch [00:39, 339.51batch/s]
# Epoch 1: 12346batch [00:40, 337.68batch/s]
# Epoch 1: 12381batch [00:40, 340.95batch/s]
# Epoch 1: 12416batch [00:40, 336.67batch/s]
# Epoch 1: 12450batch [00:40, 300.37batch/s]
# Epoch 1: 12481batch [00:40, 300.58batch/s]
# Epoch 1: 12513batch [00:40, 305.46batch/s]
# Epoch 1: 12548batch [00:40, 317.63batch/s]
# Epoch 1: 12582batch [00:40, 322.61batch/s]
# Epoch 1: 12615batch [00:40, 322.63batch/s]
# Epoch 1: 12649batch [00:41, 325.18batch/s]
# Epoch 1: 12683batch [00:41, 328.00batch/s]
# Epoch 1: 12716batch [00:41, 327.00batch/s]
# Epoch 1: 12750batch [00:41, 327.93batch/s]
# Epoch 1: 12785batch [00:41, 333.45batch/s]
# Epoch 1: 12820batch [00:41, 336.35batch/s]
# Epoch 1: 12855batch [00:41, 339.38batch/s]
# Epoch 1: 12890batch [00:41, 342.49batch/s]
# Epoch 1: 12925batch [00:41, 337.69batch/s]
# Epoch 1: 12959batch [00:41, 337.47batch/s]
# Epoch 1: 12993batch [00:42, 333.30batch/s]
# Epoch 1: 13027batch [00:42, 330.42batch/s]
# Epoch 1: 13061batch [00:42, 329.37batch/s]
# Epoch 1: 13094batch [00:42, 320.65batch/s]
# Epoch 1: 13127batch [00:42, 294.32batch/s]
# Epoch 1: 13157batch [00:42, 295.09batch/s]
# Epoch 1: 13187batch [00:42, 294.42batch/s]
# Epoch 1: 13218batch [00:42, 298.70batch/s]
# Epoch 1: 13249batch [00:42, 298.44batch/s]
# Epoch 1: 13280batch [00:43, 299.33batch/s]
# Epoch 1: 13311batch [00:43, 302.41batch/s]
# Epoch 1: 13342batch [00:43, 302.66batch/s]
# Epoch 1: 13373batch [00:43, 301.16batch/s]
# Epoch 1: 13405batch [00:43, 305.95batch/s]
# Epoch 1: 13436batch [00:43, 297.22batch/s]
# Epoch 1: 13468batch [00:43, 302.29batch/s]
# Epoch 1: 13500batch [00:43, 305.18batch/s]
# Epoch 1: 13532batch [00:43, 308.34batch/s]
# Epoch 1: 13569batch [00:43, 324.99batch/s]
# Epoch 1: 13604batch [00:44, 330.42batch/s]
# Epoch 1: 13638batch [00:44, 302.05batch/s]
# Epoch 1: 13669batch [00:44, 293.57batch/s]
# Epoch 1: 13699batch [00:44, 295.09batch/s]
# Epoch 1: 13733batch [00:44, 306.92batch/s]
# Epoch 1: 13766batch [00:44, 312.64batch/s]
# Epoch 1: 13799batch [00:44, 315.85batch/s]
# Epoch 1: 13831batch [00:44, 314.96batch/s]
# Epoch 1: 13864batch [00:44, 315.67batch/s]
# Epoch 1: 13896batch [00:45, 303.75batch/s]
# Epoch 1: 13928batch [00:45, 306.68batch/s]
# Epoch 1: 13960batch [00:45, 308.50batch/s]
# Epoch 1: 13992batch [00:45, 310.86batch/s]
# Epoch 1: 14024batch [00:45, 308.70batch/s]
# Epoch 1: 14055batch [00:45, 307.99batch/s]
# Epoch 1: 14086batch [00:45, 305.60batch/s]
# Epoch 1: 14117batch [00:45, 306.36batch/s]
# Epoch 1: 14148batch [00:45, 306.59batch/s]
# Epoch 1: 14180batch [00:45, 308.23batch/s]
# Epoch 1: 14212batch [00:46, 310.93batch/s]
# Epoch 1: 14244batch [00:46, 309.79batch/s]
# Epoch 1: 14275batch [00:46, 304.50batch/s]
# Epoch 1: 14306batch [00:46, 304.69batch/s]
# Epoch 1: 14340batch [00:46, 312.65batch/s]
# Epoch 1: 14372batch [00:46, 310.10batch/s]
# Epoch 1: 14404batch [00:46, 310.28batch/s]
# Epoch 1: 14436batch [00:46, 310.70batch/s]
# Epoch 1: 14468batch [00:46, 304.64batch/s]
# Epoch 1: 14499batch [00:46, 305.86batch/s]
# Epoch 1: 14531batch [00:47, 308.44batch/s]
# Epoch 1: 14564batch [00:47, 312.50batch/s]
# Epoch 1: 14596batch [00:47, 314.38batch/s]
# Epoch 1: 14629batch [00:47, 317.32batch/s]
# Epoch 1: 14663batch [00:47, 323.04batch/s]
# Epoch 1: 14697batch [00:47, 326.08batch/s]
# Epoch 1: 14730batch [00:47, 320.54batch/s]
# Epoch 1: 14764batch [00:47, 326.17batch/s]
# Epoch 1: 14797batch [00:47, 279.69batch/s]
# Epoch 1: 14831batch [00:48, 295.09batch/s]
# Epoch 1: 14867batch [00:48, 311.77batch/s]
# Epoch 1: 14902batch [00:48, 320.70batch/s]
# Epoch 1: 14937batch [00:48, 327.18batch/s]
# Epoch 1: 14971batch [00:48, 328.04batch/s]
# Epoch 1: 15005batch [00:48, 330.35batch/s]
# Epoch 1: 15040batch [00:48, 334.14batch/s]
# Epoch 1: 15074batch [00:48, 333.26batch/s]
# Epoch 1: 15109batch [00:48, 337.38batch/s]
# Epoch 1: 15143batch [00:48, 337.15batch/s]
# Epoch 1: 15177batch [00:49, 335.54batch/s]
# Epoch 1: 15211batch [00:49, 331.61batch/s]
# Epoch 1: 15248batch [00:49, 341.88batch/s]
# Epoch 1: 15283batch [00:49, 336.45batch/s]
# Epoch 1: 15317batch [00:49, 333.59batch/s]
# Epoch 1: 15352batch [00:49, 336.42batch/s]
# Epoch 1: 15387batch [00:49, 339.40batch/s]
# Epoch 1: 15421batch [00:49, 333.25batch/s]
# Epoch 1: 15456batch [00:49, 336.18batch/s]
# Epoch 1: 15490batch [00:50, 337.18batch/s]
# Epoch 1: 15524batch [00:50, 330.61batch/s]
# Epoch 1: 15558batch [00:50, 331.83batch/s]
# Epoch 1: 15594batch [00:50, 340.10batch/s]
# Epoch 1: 15629batch [00:50, 339.57batch/s]
# Epoch 1: 15663batch [00:50, 336.72batch/s]
# Epoch 1: 15701batch [00:50, 347.41batch/s]
# Epoch 1: 15736batch [00:50, 344.12batch/s]
# Epoch 1: 15771batch [00:50, 341.83batch/s]
# Epoch 1: 15806batch [00:50, 310.50batch/s]
# Epoch 1: 15838batch [00:51, 308.60batch/s]
# Epoch 1: 15871batch [00:51, 314.56batch/s]
# Epoch 1: 15905batch [00:51, 319.98batch/s]
# Epoch 1: 15939batch [00:51, 323.88batch/s]
# Epoch 1: 15974batch [00:51, 330.50batch/s]
# Epoch 1: 16008batch [00:51, 329.43batch/s]
# Epoch 1: 16042batch [00:51, 331.55batch/s]
# Epoch 1: 16077batch [00:51, 335.98batch/s]
# Epoch 1: 16111batch [00:51, 336.56batch/s]
# Epoch 1: 16145batch [00:52, 331.69batch/s]
# Epoch 1: 16179batch [00:52, 329.29batch/s]
# Epoch 1: 16213batch [00:52, 329.16batch/s]
# Epoch 1: 16247batch [00:52, 331.36batch/s]
# Epoch 1: 16285batch [00:52, 343.65batch/s]
# Epoch 1: 16320batch [00:52, 338.41batch/s]
# Epoch 1: 16354batch [00:52, 335.93batch/s]
# Epoch 1: 16390batch [00:52, 342.97batch/s]
# Epoch 1: 16425batch [00:52, 340.87batch/s]
# Epoch 1: 16460batch [00:52, 337.43batch/s]
# Epoch 1: 16494batch [00:53, 335.24batch/s]
# Epoch 1: 16528batch [00:53, 331.78batch/s]
# Epoch 1: 16562batch [00:53, 331.10batch/s]
# Epoch 1: 16596batch [00:53, 331.77batch/s]
# Epoch 1: 16630batch [00:53, 329.36batch/s]
# Epoch 1: 16663batch [00:53, 327.36batch/s]
# Epoch 1: 16697batch [00:53, 328.53batch/s]
# Epoch 1: 16731batch [00:53, 330.46batch/s]
# Epoch 1: 16765batch [00:53, 317.04batch/s]
# Epoch 1: 16797batch [00:53, 301.51batch/s]
# Epoch 1: 16834batch [00:54, 320.63batch/s]
# Epoch 1: 16873batch [00:54, 338.48batch/s]
# Epoch 1: 16908batch [00:54, 338.87batch/s]
# Epoch 1: 16943batch [00:54, 339.15batch/s]
# Epoch 1: 16980batch [00:54, 347.12batch/s]
# Epoch 1: 17016batch [00:54, 347.84batch/s]
# Epoch 1: 17051batch [00:54, 347.45batch/s]
# Epoch 1: 17086batch [00:54, 340.35batch/s]
# Epoch 1: 17123batch [00:54, 347.43batch/s]
# Epoch 1: 17158batch [00:55, 342.22batch/s]
# Epoch 1: 17194batch [00:55, 346.13batch/s]
# Epoch 1: 17229batch [00:55, 341.90batch/s]
# Epoch 1: 17265batch [00:55, 344.17batch/s]
# Epoch 1: 17300batch [00:55, 342.87batch/s]
# Epoch 1: 17335batch [00:55, 338.03batch/s]
# Epoch 1: 17369batch [00:55, 333.37batch/s]
# Epoch 1: 17404batch [00:55, 337.50batch/s]
# Epoch 1: 17438batch [00:55, 336.26batch/s]
# Epoch 1: 17475batch [00:55, 346.17batch/s]
# Epoch 1: 17510batch [00:56, 343.24batch/s]
# Epoch 1: 17545batch [00:56, 337.28batch/s]
# Epoch 1: 17579batch [00:56, 331.81batch/s]
# Epoch 1: 17613batch [00:56, 330.40batch/s]
# Epoch 1: 17648batch [00:56, 333.97batch/s]
# Epoch 1: 17682batch [00:56, 333.79batch/s]
# Epoch 1: 17716batch [00:56, 300.39batch/s]
# Epoch 1: 17749batch [00:56, 306.79batch/s]
# Epoch 1: 17787batch [00:56, 325.41batch/s]
# Epoch 1: 17821batch [00:57, 328.62batch/s]
# Epoch 1: 17860batch [00:57, 344.32batch/s]
# Epoch 1: 17896batch [00:57, 345.86batch/s]
# Epoch 1: 17931batch [00:57, 343.06batch/s]
# Epoch 1: 17966batch [00:57, 340.13batch/s]
# Epoch 1: 18004batch [00:57, 350.71batch/s]
# Epoch 1: 18040batch [00:57, 352.40batch/s]
# Epoch 1: 18076batch [00:57, 349.89batch/s]
# Epoch 1: 18112batch [00:57, 344.53batch/s]
# Epoch 1: 18147batch [00:57, 343.14batch/s]
# Epoch 1: 18182batch [00:58, 341.16batch/s]
# Epoch 1: 18218batch [00:58, 346.65batch/s]
# Epoch 1: 18255batch [00:58, 353.48batch/s]
# Epoch 1: 18291batch [00:58, 339.35batch/s]
# Epoch 1: 18326batch [00:58, 342.14batch/s]
# Epoch 1: 18361batch [00:58, 339.49batch/s]
# Epoch 1: 18398batch [00:58, 346.34batch/s]
# Epoch 1: 18433batch [00:58, 331.89batch/s]
# Epoch 1: 18467batch [00:58, 324.42batch/s]
# Epoch 1: 18500batch [00:59, 324.20batch/s]
# Epoch 1: 18534batch [00:59, 326.86batch/s]
# Epoch 1: 18567batch [00:59, 326.82batch/s]
# Epoch 1: 18600batch [00:59, 327.61batch/s]
# Epoch 1: 18633batch [00:59, 328.02batch/s]
# Epoch 1: 18666batch [00:59, 290.69batch/s]
# Epoch 1: 18700batch [00:59, 303.75batch/s]
# Epoch 1: 18733batch [00:59, 309.36batch/s]
# Epoch 1: 18765batch [00:59, 305.10batch/s]
# Epoch 1: 18796batch [00:59, 298.85batch/s]
# Epoch 1: 18829batch [01:00, 306.52batch/s]
# Epoch 1: 18863batch [01:00, 314.03batch/s]
# Epoch 1: 18896batch [01:00, 318.25batch/s]
# Epoch 1: 18931batch [01:00, 327.07batch/s]
# Epoch 1: 18965batch [01:00, 327.98batch/s]
# Epoch 1: 18998batch [01:00, 326.65batch/s]
# Epoch 1: 19036batch [01:00, 341.37batch/s]
# Epoch 1: 19071batch [01:00, 338.81batch/s]
# Epoch 1: 19105batch [01:00, 331.71batch/s]
# Epoch 1: 19139batch [01:01, 331.73batch/s]
# Epoch 1: 19173batch [01:01, 331.24batch/s]
# Epoch 1: 19210batch [01:01, 339.61batch/s]
# Epoch 1: 19244batch [01:01, 335.78batch/s]
# Epoch 1: 19278batch [01:01, 336.04batch/s]
# Epoch 1: 19315batch [01:01, 345.01batch/s]
# Epoch 1: 19354batch [01:01, 357.24batch/s]
# Epoch 1: 19390batch [01:01, 349.77batch/s]
# Epoch 1: 19426batch [01:01, 334.92batch/s]
# Epoch 1: 19462batch [01:01, 339.99batch/s]
# Epoch 1: 19497batch [01:02, 340.91batch/s]
# Epoch 1: 19533batch [01:02, 345.44batch/s]
# Epoch 1: 19568batch [01:02, 334.08batch/s]
# Epoch 1: 19602batch [01:02, 301.20batch/s]
# Epoch 1: 19639batch [01:02, 318.83batch/s]
# Epoch 1: 19672batch [01:02, 321.41batch/s]
# Epoch 1: 19706batch [01:02, 324.08batch/s]
# Epoch 1: 19739batch [01:02, 299.78batch/s]
# Epoch 1: 19773batch [01:02, 309.93batch/s]
# Epoch 1: 19806batch [01:03, 314.63batch/s]
# Epoch 1: 19839batch [01:03, 318.71batch/s]
# Epoch 1: 19873batch [01:03, 323.00batch/s]
# Epoch 1: 19908batch [01:03, 330.87batch/s]
# Epoch 1: 19944batch [01:03, 338.44batch/s]
# Epoch 1: 19978batch [01:03, 338.90batch/s]
# Epoch 1: 20012batch [01:03, 338.95batch/s]
# Epoch 1: 20047batch [01:03, 341.48batch/s]
# Epoch 1: 20082batch [01:03, 339.97batch/s]
# Epoch 1: 20117batch [01:03, 340.92batch/s]
# Epoch 1: 20152batch [01:04, 341.58batch/s]
# Epoch 1: 20187batch [01:04, 341.43batch/s]
# Epoch 1: 20222batch [01:04, 338.95batch/s]
# Epoch 1: 20256batch [01:04, 337.28batch/s]
# Epoch 1: 20290batch [01:04, 337.09batch/s]
# Epoch 1: 20324batch [01:04, 336.37batch/s]
# Epoch 1: 20358batch [01:04, 334.27batch/s]
# Epoch 1: 20392batch [01:04, 334.81batch/s]
# Epoch 1: 20427batch [01:04, 337.01batch/s]
# Epoch 1: 20461batch [01:05, 305.44batch/s]
# Epoch 1: 20493batch [01:05, 300.31batch/s]
# Epoch 1: 20528batch [01:05, 313.20batch/s]
# Epoch 1: 20562batch [01:05, 318.98batch/s]
# Epoch 1: 20598batch [01:05, 330.74batch/s]
# Epoch 1: 20633batch [01:05, 335.36batch/s]
# Epoch 1: 20667batch [01:05, 333.79batch/s]
# Epoch 1: 20701batch [01:05, 330.71batch/s]
# Epoch 1: 20735batch [01:05, 330.71batch/s]
# Epoch 1: 20770batch [01:05, 335.38batch/s]
# Epoch 1: 20804batch [01:06, 335.75batch/s]
# Epoch 1: 20840batch [01:06, 341.90batch/s]
# Epoch 1: 20875batch [01:06, 343.28batch/s]
# Epoch 1: 20910batch [01:06, 340.23batch/s]
# Epoch 1: 20945batch [01:06, 340.10batch/s]
# Epoch 1: 20980batch [01:06, 339.63batch/s]
# Epoch 1: 21017batch [01:06, 345.82batch/s]
# Epoch 1: 21052batch [01:06, 345.02batch/s]
# Epoch 1: 21087batch [01:06, 341.46batch/s]
# Epoch 1: 21122batch [01:06, 335.12batch/s]
# Epoch 1: 21156batch [01:07, 327.98batch/s]
# Epoch 1: 21189batch [01:07, 277.44batch/s]
# Epoch 1: 21220batch [01:07, 285.81batch/s]
# Epoch 1: 21252batch [01:07, 293.47batch/s]
# Epoch 1: 21285batch [01:07, 302.73batch/s]
# Epoch 1: 21318batch [01:07, 308.69batch/s]
# Epoch 1: 21350batch [01:07, 280.35batch/s]
# Epoch 1: 21385batch [01:07, 298.28batch/s]
# Epoch 1: 21417batch [01:07, 304.29batch/s]
# Epoch 1: 21451batch [01:08, 313.51batch/s]
# Epoch 1: 21485batch [01:08, 319.30batch/s]
# Epoch 1: 21521batch [01:08, 330.11batch/s]
# Epoch 1: 21556batch [01:08, 334.85batch/s]
# Epoch 1: 21590batch [01:08, 335.38batch/s]
# Epoch 1: 21624batch [01:08, 324.30batch/s]
# Epoch 1: 21661batch [01:08, 335.56batch/s]
# Epoch 1: 21695batch [01:08, 333.57batch/s]
# Epoch 1: 21729batch [01:08, 331.16batch/s]
# Epoch 1: 21764batch [01:09, 336.42batch/s]
# Epoch 1: 21798batch [01:09, 337.46batch/s]
# Epoch 1: 21833batch [01:09, 340.17batch/s]
# Epoch 1: 21868batch [01:09, 338.54batch/s]
# Epoch 1: 21906batch [01:09, 348.68batch/s]
# Epoch 1: 21941batch [01:09, 348.04batch/s]
# Epoch 1: 21980batch [01:09, 359.39batch/s]
# Epoch 1: 22016batch [01:09, 353.20batch/s]
# Epoch 1: 22052batch [01:09, 350.05batch/s]
# Epoch 1: 22088batch [01:09, 341.96batch/s]
# Epoch 1: 22123batch [01:10, 340.35batch/s]
# Epoch 1: 22158batch [01:10, 338.25batch/s]
# Epoch 1: 22192batch [01:10, 296.65batch/s]
# Epoch 1: 22225batch [01:10, 304.52batch/s]
# Epoch 1: 22258batch [01:10, 310.97batch/s]
# Epoch 1: 22291batch [01:10, 315.40batch/s]
# Epoch 1: 22325batch [01:10, 321.52batch/s]
# Epoch 1: 22359batch [01:10, 326.32batch/s]
# Epoch 1: 22392batch [01:10, 326.44batch/s]
# Epoch 1: 22425batch [01:11, 326.53batch/s]
# Epoch 1: 22461batch [01:11, 335.42batch/s]
# Epoch 1: 22495batch [01:11, 333.81batch/s]
# Epoch 1: 22530batch [01:11, 336.60batch/s]
# Epoch 1: 22565batch [01:11, 338.56batch/s]
# Epoch 1: 22599batch [01:11, 333.97batch/s]
# Epoch 1: 22635batch [01:11, 341.56batch/s]
# Epoch 1: 22670batch [01:11, 340.88batch/s]
# Epoch 1: 22705batch [01:11, 336.51batch/s]
# Epoch 1: 22740batch [01:11, 337.90batch/s]
# Epoch 1: 22774batch [01:12, 336.54batch/s]
# Epoch 1: 22808batch [01:12, 335.59batch/s]
# Epoch 1: 22843batch [01:12, 338.83batch/s]
# Epoch 1: 22877batch [01:12, 337.18batch/s]
# Epoch 1: 22911batch [01:12, 332.57batch/s]
# Epoch 1: 22949batch [01:12, 343.62batch/s]
# Epoch 1: 22984batch [01:12, 345.38batch/s]
# Epoch 1: 23019batch [01:12, 346.74batch/s]
# Epoch 1: 23054batch [01:12, 300.57batch/s]
# Epoch 1: 23087batch [01:13, 308.47batch/s]
# Epoch 1: 23123batch [01:13, 321.85batch/s]
# Epoch 1: 23159batch [01:13, 331.11batch/s]
# Epoch 1: 23194batch [01:13, 335.08batch/s]
# Epoch 1: 23229batch [01:13, 338.82batch/s]
# Epoch 1: 23264batch [01:13, 339.98batch/s]
# Epoch 1: 23299batch [01:13, 333.14batch/s]
# Epoch 1: 23333batch [01:13, 331.95batch/s]
# Epoch 1: 23367batch [01:13, 332.35batch/s]
# Epoch 1: 23401batch [01:13, 330.25batch/s]
# Epoch 1: 23437batch [01:14, 336.96batch/s]
# Epoch 1: 23471batch [01:14, 337.85batch/s]
# Epoch 1: 23505batch [01:14, 334.96batch/s]
# Epoch 1: 23539batch [01:14, 334.44batch/s]
# Epoch 1: 23574batch [01:14, 336.18batch/s]
# Epoch 1: 23609batch [01:14, 338.91batch/s]
# Epoch 1: 23644batch [01:14, 341.18batch/s]
# Epoch 1: 23679batch [01:14, 341.76batch/s]
# Epoch 1: 23714batch [01:14, 342.96batch/s]
# Epoch 1: 23749batch [01:14, 344.03batch/s]
# Epoch 1: 23784batch [01:15, 340.69batch/s]
# Epoch 1: 23819batch [01:15, 338.45batch/s]
# Epoch 1: 23855batch [01:15, 343.74batch/s]
# Epoch 1: 23890batch [01:15, 339.58batch/s]
# Epoch 1: 23924batch [01:15, 304.48batch/s]
# Epoch 1: 23958batch [01:15, 313.31batch/s]
# Epoch 1: 23993batch [01:15, 321.77batch/s]
# Epoch 1: 24026batch [01:15, 320.69batch/s]
# Epoch 1: 24059batch [01:15, 320.41batch/s]
# Epoch 1: 24092batch [01:16, 321.58batch/s]
# Epoch 1: 24131batch [01:16, 340.50batch/s]
# Epoch 1: 24166batch [01:16, 339.31batch/s]
# Epoch 1: 24201batch [01:16, 339.46batch/s]
# Epoch 1: 24236batch [01:16, 336.47batch/s]
# Epoch 1: 24270batch [01:16, 333.61batch/s]
# Epoch 1: 24304batch [01:16, 333.53batch/s]
# Epoch 1: 24338batch [01:16, 325.26batch/s]
# Epoch 1: 24371batch [01:16, 326.62batch/s]
# Epoch 1: 24404batch [01:16, 325.62batch/s]
# Epoch 1: 24437batch [01:17, 321.25batch/s]
# Epoch 1: 24471batch [01:17, 325.66batch/s]
# Epoch 1: 24504batch [01:17, 324.44batch/s]
# Epoch 1: 24538batch [01:17, 329.01batch/s]
# Epoch 1: 24574batch [01:17, 336.18batch/s]
# Epoch 1: 24609batch [01:17, 337.27batch/s]
# Epoch 1: 24643batch [01:17, 334.13batch/s]
# Epoch 1: 24680batch [01:17, 343.67batch/s]
# Epoch 1: 24718batch [01:17, 353.35batch/s]
# Epoch 1: 24754batch [01:17, 345.11batch/s]
# Epoch 1: 24789batch [01:18, 343.53batch/s]
# Epoch 1: 24824batch [01:18, 301.32batch/s]
# Epoch 1: 24857batch [01:18, 308.39batch/s]
# Epoch 1: 24891batch [01:18, 315.37batch/s]
# Epoch 1: 24924batch [01:18, 319.48batch/s]
# Epoch 1: 24959batch [01:18, 325.43batch/s]
# Epoch 1: 24994batch [01:18, 330.07batch/s]
# Epoch 1: 25028batch [01:18, 322.24batch/s]
# Epoch 1: 25063batch [01:18, 328.32batch/s]
# Epoch 1: 25097batch [01:19, 330.46batch/s]
# Epoch 1: 25135batch [01:19, 343.58batch/s]
# Epoch 1: 25170batch [01:19, 341.46batch/s]
# Epoch 1: 25205batch [01:19, 341.96batch/s]
# Epoch 1: 25240batch [01:19, 340.32batch/s]
# Epoch 1: 25275batch [01:19, 340.17batch/s]
# Epoch 1: 25310batch [01:19, 328.04batch/s]
# Epoch 1: 25345batch [01:19, 332.42batch/s]
# Epoch 1: 25379batch [01:19, 331.45batch/s]
# Epoch 1: 25413batch [01:19, 331.06batch/s]
# Epoch 1: 25448batch [01:20, 334.62batch/s]
# Epoch 1: 25486batch [01:20, 347.90batch/s]
# Epoch 1: 25524batch [01:20, 356.32batch/s]
# Epoch 1: 25560batch [01:20, 352.95batch/s]
# Epoch 1: 25596batch [01:20, 345.86batch/s]
# Epoch 1: 25635batch [01:20, 355.59batch/s]
# Epoch 1: 25671batch [01:20, 348.74batch/s]
# Epoch 1: 25706batch [01:20, 344.71batch/s]
# Epoch 1: 25741batch [01:20, 299.52batch/s]
# Epoch 1: 25778batch [01:21, 317.28batch/s]
# Epoch 1: 25813batch [01:21, 324.44batch/s]
# Epoch 1: 25847batch [01:21, 326.96batch/s]
# Epoch 1: 25886batch [01:21, 341.97batch/s]
# Epoch 1: 25921batch [01:21, 339.40batch/s]
# Epoch 1: 25956batch [01:21, 336.63batch/s]
# Epoch 1: 25991batch [01:21, 338.53batch/s]
# Epoch 1: 26025batch [01:21, 335.24batch/s]
# Epoch 1: 26060batch [01:21, 336.60batch/s]
# Epoch 1: 26094batch [01:22, 335.85batch/s]
# Epoch 1: 26128batch [01:22, 335.61batch/s]
# Epoch 1: 26165batch [01:22, 343.46batch/s]
# Epoch 1: 26201batch [01:22, 347.31batch/s]
# Epoch 1: 26238batch [01:22, 350.91batch/s]
# Epoch 1: 26274batch [01:22, 347.44batch/s]
# Epoch 1: 26309batch [01:22, 345.16batch/s]
# Epoch 1: 26344batch [01:22, 341.39batch/s]
# Epoch 1: 26379batch [01:22, 340.54batch/s]
# Epoch 1: 26414batch [01:22, 335.69batch/s]
# Epoch 1: 26449batch [01:23, 338.00batch/s]
# Epoch 1: 26483batch [01:23, 336.40batch/s]
# Epoch 1: 26523batch [01:23, 352.96batch/s]
# Epoch 1: 26559batch [01:23, 307.98batch/s]
# Epoch 1: 26592batch [01:23, 313.02batch/s]
# Epoch 1: 26626batch [01:23, 318.70batch/s]
# Epoch 1: 26660batch [01:23, 323.78batch/s]
# Epoch 1: 26694batch [01:23, 328.13batch/s]
# Epoch 1: 26728batch [01:23, 329.48batch/s]
# Epoch 1: 26762batch [01:24, 329.23batch/s]
# Epoch 1: 26798batch [01:24, 336.87batch/s]
# Epoch 1: 26833batch [01:24, 337.75batch/s]
# Epoch 1: 26867batch [01:24, 336.44batch/s]
# Epoch 1: 26902batch [01:24, 338.44batch/s]
# Epoch 1: 26939batch [01:24, 347.74batch/s]
# Epoch 1: 26974batch [01:24, 344.33batch/s]
# Epoch 1: 27009batch [01:24, 342.97batch/s]
# Epoch 1: 27044batch [01:24, 344.02batch/s]
# Epoch 1: 27081batch [01:24, 351.70batch/s]
# Epoch 1: 27117batch [01:25, 346.96batch/s]
# Epoch 1: 27152batch [01:25, 344.81batch/s]
# Epoch 1: 27187batch [01:25, 346.34batch/s]
# Epoch 1: 27222batch [01:25, 344.37batch/s]
# Epoch 1: 27257batch [01:25, 342.99batch/s]
# Epoch 1: 27292batch [01:25, 342.03batch/s]
# Epoch 1: 27327batch [01:25, 341.36batch/s]
# Epoch 1: 27362batch [01:25, 342.90batch/s]
# Epoch 1: 27398batch [01:25, 345.90batch/s]
# Epoch 1: 27433batch [01:25, 339.10batch/s]
# Epoch 1: 27467batch [01:26, 300.40batch/s]
# Epoch 1: 27501batch [01:26, 309.52batch/s]
# Epoch 1: 27535batch [01:26, 315.80batch/s]
# Epoch 1: 27572batch [01:26, 331.10batch/s]
# Epoch 1: 27606batch [01:26, 331.75batch/s]
# Epoch 1: 27641batch [01:26, 336.83batch/s]
# Epoch 1: 27676batch [01:26, 337.72batch/s]
# Epoch 1: 27711batch [01:26, 340.31batch/s]
# Epoch 1: 27746batch [01:26, 340.16batch/s]
# Epoch 1: 27781batch [01:27, 338.08batch/s]
# Epoch 1: 27815batch [01:27, 336.11batch/s]
# Epoch 1: 27850batch [01:27, 338.44batch/s]
# Epoch 1: 27886batch [01:27, 344.78batch/s]
# Epoch 1: 27922batch [01:27, 348.26batch/s]
# Epoch 1: 27957batch [01:27, 342.68batch/s]
# Epoch 1: 27992batch [01:27, 339.83batch/s]
# Epoch 1: 28027batch [01:27, 342.81batch/s]
# Epoch 1: 28062batch [01:27, 343.91batch/s]
# Epoch 1: 28097batch [01:27, 340.49batch/s]
# Epoch 1: 28133batch [01:28, 345.59batch/s]
# Epoch 1: 28168batch [01:28, 344.86batch/s]
# Epoch 1: 28207batch [01:28, 357.14batch/s]
# Epoch 1: 28246batch [01:28, 363.64batch/s]
# Epoch 1: 28283batch [01:28, 356.05batch/s]
# Epoch 1: 28319batch [01:28, 348.07batch/s]
# Epoch 1: 28354batch [01:28, 324.60batch/s]
# Epoch 1: 28387batch [01:28, 306.54batch/s]
# Epoch 1: 28424batch [01:28, 322.89batch/s]
# Epoch 1: 28458batch [01:29, 326.35batch/s]
# Epoch 1: 28493batch [01:29, 330.75batch/s]
# Epoch 1: 28527batch [01:29, 326.84batch/s]
# Epoch 1: 28562batch [01:29, 332.53batch/s]
# Epoch 1: 28599batch [01:29, 342.40batch/s]
# Epoch 1: 28636batch [01:29, 347.43batch/s]
# Epoch 1: 28673batch [01:29, 351.97batch/s]
# Epoch 1: 28709batch [01:29, 346.01batch/s]
# Epoch 1: 28746batch [01:29, 352.46batch/s]
# Epoch 1: 28782batch [01:29, 345.24batch/s]
# Epoch 1: 28819batch [01:30, 350.38batch/s]
# Epoch 1: 28855batch [01:30, 352.16batch/s]
# Epoch 1: 28891batch [01:30, 350.35batch/s]
# Epoch 1: 28927batch [01:30, 346.08batch/s]
# Epoch 1: 28962batch [01:30, 346.21batch/s]
# Epoch 1: 28997batch [01:30, 344.30batch/s]
# Epoch 1: 29033batch [01:30, 348.73batch/s]
# Epoch 1: 29068batch [01:30, 345.03batch/s]
# Epoch 1: 29103batch [01:30, 341.31batch/s]
# Epoch 1: 29138batch [01:30, 336.21batch/s]
# Epoch 1: 29172batch [01:31, 337.25batch/s]
# Epoch 1: 29206batch [01:31, 296.85batch/s]
# Epoch 1: 29241batch [01:31, 308.65batch/s]
# Epoch 1: 29275batch [01:31, 316.43batch/s]
# Epoch 1: 29309batch [01:31, 323.07batch/s]
# Epoch 1: 29348batch [01:31, 340.35batch/s]
# Epoch 1: 29386batch [01:31, 350.20batch/s]
# Epoch 1: 29422batch [01:31, 345.55batch/s]
# Epoch 1: 29457batch [01:31, 340.90batch/s]
# Epoch 1: 29492batch [01:32, 340.13batch/s]
# Epoch 1: 29529batch [01:32, 347.36batch/s]
# Epoch 1: 29564batch [01:32, 346.11batch/s]
# Epoch 1: 29599batch [01:32, 345.22batch/s]
# Epoch 1: 29634batch [01:32, 341.61batch/s]
# Epoch 1: 29669batch [01:32, 342.06batch/s]
# Epoch 1: 29707batch [01:32, 350.85batch/s]
# Epoch 1: 29744batch [01:32, 356.48batch/s]
# Epoch 1: 29780batch [01:32, 352.31batch/s]
# Epoch 1: 29816batch [01:32, 354.57batch/s]
# Epoch 1: 29853batch [01:33, 358.41batch/s]
# Epoch 1: 29889batch [01:33, 354.67batch/s]
# Epoch 1: 29925batch [01:33, 353.28batch/s]
# Epoch 1: 29962batch [01:33, 355.59batch/s]
# Epoch 1: 29998batch [01:33, 352.66batch/s]
# Epoch 1: 30034batch [01:33, 350.04batch/s]
# Epoch 1: 30070batch [01:33, 302.38batch/s]
# Epoch 1: 30102batch [01:33, 301.76batch/s]
# Epoch 1: 30133batch [01:33, 299.06batch/s]
# Epoch 1: 30165batch [01:34, 303.64batch/s]
# Epoch 1: 30198batch [01:34, 309.42batch/s]
# Epoch 1: 30233batch [01:34, 320.08batch/s]
# Epoch 1: 30269batch [01:34, 329.95batch/s]
# Epoch 1: 30306batch [01:34, 340.63batch/s]
# Epoch 1: 30344batch [01:34, 351.14batch/s]
# Epoch 1: 30380batch [01:34, 353.48batch/s]
# Epoch 1: 30416batch [01:34, 350.23batch/s]
# Epoch 1: 30452batch [01:34, 346.89batch/s]
# Epoch 1: 30487batch [01:34, 342.41batch/s]
# Epoch 1: 30522batch [01:35, 340.65batch/s]
# Epoch 1: 30557batch [01:35, 339.30batch/s]
# Epoch 1: 30592batch [01:35, 339.97batch/s]
# Epoch 1: 30627batch [01:35, 339.36batch/s]
# Epoch 1: 30663batch [01:35, 342.40batch/s]
# Epoch 1: 30698batch [01:35, 339.11batch/s]
# Epoch 1: 30733batch [01:35, 340.30batch/s]
# Epoch 1: 30768batch [01:35, 339.74batch/s]
# Epoch 1: 30802batch [01:35, 338.84batch/s]
# Epoch 1: 30836batch [01:36, 337.61batch/s]
# Epoch 1: 30870batch [01:36, 336.23batch/s]
# Epoch 1: 30904batch [01:36, 335.06batch/s]
# Epoch 1: 30941batch [01:36, 343.35batch/s]
# Epoch 1: 30976batch [01:36, 303.61batch/s]
# Epoch 1: 31011batch [01:36, 315.18batch/s]
# Epoch 1: 31046batch [01:36, 324.75batch/s]
# Epoch 1: 31082batch [01:36, 333.73batch/s]
# Epoch 1: 31117batch [01:36, 335.96batch/s]
# Epoch 1: 31151batch [01:36, 335.18batch/s]
# Epoch 1: 31186batch [01:37, 337.54batch/s]
# Epoch 1: 31221batch [01:37, 339.20batch/s]
# Epoch 1: 31257batch [01:37, 344.31batch/s]
# Epoch 1: 31292batch [01:37, 343.95batch/s]
# Epoch 1: 31329batch [01:37, 350.61batch/s]
# Epoch 1: 31366batch [01:37, 356.35batch/s]
# Epoch 1: 31402batch [01:37, 350.15batch/s]
# Epoch 1: 31438batch [01:37, 349.75batch/s]
# Epoch 1: 31474batch [01:37, 345.65batch/s]
# Epoch 1: 31509batch [01:38, 342.92batch/s]
# Epoch 1: 31544batch [01:38, 340.71batch/s]
# Epoch 1: 31579batch [01:38, 342.13batch/s]
# Epoch 1: 31617batch [01:38, 351.18batch/s]
# Epoch 1: 31653batch [01:38, 351.70batch/s]
# Epoch 1: 31691batch [01:38, 357.93batch/s]
# Epoch 1: 31728batch [01:38, 358.32batch/s]
# Epoch 1: 31764batch [01:38, 351.57batch/s]
# Epoch 1: 31801batch [01:38, 354.11batch/s]
# Epoch 1: 31837batch [01:38, 350.31batch/s]
# Epoch 1: 31873batch [01:39, 348.74batch/s]
# Epoch 1: 31908batch [01:39, 309.96batch/s]
# Epoch 1: 31943batch [01:39, 319.90batch/s]
# Epoch 1: 31978batch [01:39, 326.45batch/s]
# Epoch 1: 32017batch [01:39, 342.49batch/s]
# Epoch 1: 32052batch [01:39, 334.11batch/s]
# Epoch 1: 32087batch [01:39, 337.66batch/s]
# Epoch 1: 32122batch [01:39, 338.76batch/s]
# Epoch 1: 32157batch [01:39, 340.98batch/s]
# Epoch 1: 32192batch [01:40, 336.62batch/s]
# Epoch 1: 32231batch [01:40, 350.61batch/s]
# Epoch 1: 32267batch [01:40, 346.27batch/s]
# Epoch 1: 32306batch [01:40, 357.93batch/s]
# Epoch 1: 32342batch [01:40, 356.45batch/s]
# Epoch 1: 32379batch [01:40, 359.37batch/s]
# Epoch 1: 32417batch [01:40, 365.45batch/s]
# Epoch 1: 32454batch [01:40, 363.57batch/s]
# Epoch 1: 32491batch [01:40, 353.36batch/s]
# Epoch 1: 32527batch [01:40, 347.72batch/s]
# Epoch 1: 32562batch [01:41, 345.08batch/s]
# Epoch 1: 32597batch [01:41, 341.41batch/s]
# Epoch 1: 32632batch [01:41, 340.57batch/s]
# Epoch 1: 32669batch [01:41, 346.84batch/s]
# Epoch 1: 32704batch [01:41, 345.75batch/s]
# Epoch 1: 32739batch [01:41, 344.97batch/s]
# Epoch 1: 32775batch [01:41, 347.35batch/s]
# Epoch 1: 32813batch [01:41, 356.86batch/s]
# Epoch 1: 32849batch [01:41, 309.79batch/s]
# Epoch 1: 32882batch [01:42, 314.89batch/s]
# Epoch 1: 32916batch [01:42, 320.65batch/s]
# Epoch 1: 32953batch [01:42, 333.65batch/s]
# Epoch 1: 32989batch [01:42, 339.27batch/s]
# Epoch 1: 33024batch [01:42, 341.39batch/s]
# Epoch 1: 33060batch [01:42, 345.81batch/s]
# Epoch 1: 33095batch [01:42, 346.03batch/s]
# Epoch 1: 33130batch [01:42, 343.15batch/s]
# Epoch 1: 33165batch [01:42, 344.15batch/s]
# Epoch 1: 33200batch [01:42, 345.88batch/s]
# Epoch 1: 33235batch [01:43, 344.04batch/s]
# Epoch 1: 33273batch [01:43, 353.63batch/s]
# Epoch 1: 33309batch [01:43, 351.35batch/s]
# Epoch 1: 33345batch [01:43, 352.86batch/s]
# Epoch 1: 33384batch [01:43, 362.78batch/s]
# Epoch 1: 33422batch [01:43, 365.64batch/s]
# Epoch 1: 33459batch [01:43, 359.29batch/s]
# Epoch 1: 33497batch [01:43, 362.68batch/s]
# Epoch 1: 33534batch [01:43, 355.44batch/s]
# Epoch 1: 33570batch [01:43, 347.67batch/s]
# Epoch 1: 33605batch [01:44, 344.53batch/s]
# Epoch 1: 33640batch [01:44, 342.74batch/s]
# Epoch 1: 33677batch [01:44, 349.46batch/s]
# Epoch 1: 33714batch [01:44, 354.43batch/s]
# Epoch 1: 33750batch [01:44, 318.19batch/s]
# Epoch 1: 33783batch [01:44, 319.52batch/s]
# Epoch 1: 33818batch [01:44, 326.90batch/s]
# Epoch 1: 33852batch [01:44, 321.00batch/s]
# Epoch 1: 33885batch [01:44, 322.63batch/s]
# Epoch 1: 33919batch [01:45, 324.82batch/s]
# Epoch 1: 33958batch [01:45, 341.70batch/s]
# Epoch 1: 33994batch [01:45, 345.02batch/s]
# Epoch 1: 34033batch [01:45, 358.18batch/s]
# Epoch 1: 34069batch [01:45, 354.54batch/s]
# Epoch 1: 34108batch [01:45, 361.77batch/s]
# Epoch 1: 34145batch [01:45, 354.80batch/s]
# Epoch 1: 34181batch [01:45, 356.11batch/s]
# Epoch 1: 34217batch [01:45, 346.57batch/s]
# Epoch 1: 34255batch [01:45, 353.97batch/s]
# Epoch 1: 34291batch [01:46, 351.63batch/s]
# Epoch 1: 34327batch [01:46, 348.99batch/s]
# Epoch 1: 34365batch [01:46, 354.91batch/s]
# Epoch 1: 34401batch [01:46, 354.33batch/s]
# Epoch 1: 34437batch [01:46, 351.87batch/s]
# Epoch 1: 34476batch [01:46, 359.87batch/s]
# Epoch 1: 34513batch [01:46, 357.60batch/s]
# Epoch 1: 34549batch [01:46, 352.94batch/s]
# Epoch 1: 34585batch [01:46, 348.90batch/s]
# Epoch 1: 34623batch [01:47, 354.84batch/s]
# Epoch 1: 34659batch [01:47, 350.22batch/s]
# Epoch 1: 34695batch [01:47, 307.75batch/s]
# Epoch 1: 34731batch [01:47, 319.92batch/s]
# Epoch 1: 34770batch [01:47, 337.27batch/s]
# Epoch 1: 34807batch [01:47, 344.51batch/s]
# Epoch 1: 34842batch [01:47, 336.49batch/s]
# Epoch 1: 34877batch [01:47, 339.36batch/s]
# Epoch 1: 34912batch [01:47, 342.08batch/s]
# Epoch 1: 34947batch [01:48, 338.47batch/s]
# Epoch 1: 34981batch [01:48, 338.91batch/s]
# Epoch 1: 35016batch [01:48, 340.01batch/s]
# Epoch 1: 35051batch [01:48, 338.85batch/s]
# Epoch 1: 35085batch [01:48, 336.89batch/s]
# Epoch 1: 35123batch [01:48, 349.34batch/s]
# Epoch 1: 35160batch [01:48, 352.32batch/s]
# Epoch 1: 35196batch [01:48, 346.19batch/s]
# Epoch 1: 35232batch [01:48, 349.85batch/s]
# Epoch 1: 35268batch [01:48, 352.83batch/s]
# Epoch 1: 35304batch [01:49, 345.70batch/s]
# Epoch 1: 35340batch [01:49, 348.47batch/s]
# Epoch 1: 35375batch [01:49, 346.89batch/s]
# Epoch 1: 35413batch [01:49, 356.62batch/s]
# Epoch 1: 35449batch [01:49, 350.37batch/s]
# Epoch 1: 35485batch [01:49, 353.19batch/s]
# Epoch 1: 35521batch [01:49, 348.25batch/s]
# Epoch 1: 35557batch [01:49, 350.55batch/s]
# Epoch 1: 35593batch [01:49, 307.02batch/s]
# Epoch 1: 35626batch [01:50, 311.49batch/s]
# Epoch 1: 35662batch [01:50, 323.95batch/s]
# Epoch 1: 35698batch [01:50, 333.17batch/s]
# Epoch 1: 35733batch [01:50, 335.12batch/s]
# Epoch 1: 35768batch [01:50, 336.87batch/s]
# Epoch 1: 35802batch [01:50, 334.93batch/s]
# Epoch 1: 35836batch [01:50, 335.78batch/s]
# Epoch 1: 35870batch [01:50, 335.89batch/s]
# Epoch 1: 35905batch [01:50, 337.13batch/s]
# Epoch 1: 35939batch [01:50, 333.70batch/s]
# Epoch 1: 35973batch [01:51, 333.21batch/s]
# Epoch 1: 36007batch [01:51, 333.25batch/s]
# Epoch 1: 36041batch [01:51, 334.25batch/s]
# Epoch 1: 36076batch [01:51, 336.91batch/s]
# Epoch 1: 36111batch [01:51, 337.79batch/s]
# Epoch 1: 36145batch [01:51, 336.45batch/s]
# Epoch 1: 36181batch [01:51, 342.40batch/s]
# Epoch 1: 36216batch [01:51, 341.61batch/s]
# Epoch 1: 36251batch [01:51, 338.97batch/s]
# Epoch 1: 36285batch [01:51, 339.03batch/s]
# Epoch 1: 36324batch [01:52, 352.70batch/s]
# Epoch 1: 36360batch [01:52, 352.00batch/s]
# Epoch 1: 36396batch [01:52, 347.97batch/s]
# Epoch 1: 36431batch [01:52, 344.87batch/s]
# Epoch 1: 36466batch [01:52, 304.10batch/s]
# Epoch 1: 36500batch [01:52, 312.90batch/s]
# Epoch 1: 36534batch [01:52, 318.64batch/s]
# Epoch 1: 36569batch [01:52, 324.85batch/s]
# Epoch 1: 36605batch [01:52, 333.94batch/s]
# Epoch 1: 36639batch [01:53, 331.85batch/s]
# Epoch 1: 36675batch [01:53, 337.76batch/s]
# Epoch 1: 36710batch [01:53, 339.35batch/s]
# Epoch 1: 36745batch [01:53, 340.47batch/s]
# Epoch 1: 36783batch [01:53, 350.03batch/s]
# Epoch 1: 36822batch [01:53, 360.73batch/s]
# Epoch 1: 36859batch [01:53, 359.23batch/s]
# Epoch 1: 36898batch [01:53, 366.13batch/s]
# Epoch 1: 36935batch [01:53, 363.42batch/s]
# Epoch 1: 36972batch [01:53, 354.92batch/s]
# Epoch 1: 37008batch [01:54, 350.30batch/s]
# Epoch 1: 37047batch [01:54, 359.71batch/s]
# Epoch 1: 37084batch [01:54, 352.44batch/s]
# Epoch 1: 37120batch [01:54, 353.60batch/s]
# Epoch 1: 37156batch [01:54, 350.37batch/s]
# Epoch 1: 37192batch [01:54, 346.13batch/s]
# Epoch 1: 37227batch [01:54, 342.30batch/s]
# Epoch 1: 37262batch [01:54, 340.58batch/s]
# Epoch 1: 37298batch [01:54, 344.22batch/s]
# Epoch 1: 37333batch [01:55, 300.33batch/s]
# Epoch 1: 37367batch [01:55, 310.05batch/s]
# Epoch 1: 37404batch [01:55, 323.85batch/s]
# Epoch 1: 37439batch [01:55, 331.17batch/s]
# Epoch 1: 37473batch [01:55, 332.75batch/s]
# Epoch 1: 37509batch [01:55, 339.65batch/s]
# Epoch 1: 37544batch [01:55, 340.68batch/s]
# Epoch 1: 37581batch [01:55, 346.23batch/s]
# Epoch 1: 37616batch [01:55, 343.31batch/s]
# Epoch 1: 37651batch [01:55, 340.28batch/s]
# Epoch 1: 37686batch [01:56, 341.06batch/s]
# Epoch 1: 37721batch [01:56, 343.68batch/s]
# Epoch 1: 37757batch [01:56, 346.45batch/s]
# Epoch 1: 37792batch [01:56, 343.44batch/s]
# Epoch 1: 37827batch [01:56, 343.35batch/s]
# Epoch 1: 37862batch [01:56, 344.30batch/s]
# Epoch 1: 37899batch [01:56, 349.83batch/s]
# Epoch 1: 37934batch [01:56, 349.50batch/s]
# Epoch 1: 37971batch [01:56, 354.53batch/s]
# Epoch 1: 38008batch [01:56, 357.01batch/s]
# Epoch 1: 38044batch [01:57, 352.66batch/s]
# Epoch 1: 38080batch [01:57, 353.78batch/s]
# ...
# Epoch 1: 211943batch [10:44, 330.13batch/s]
# Epoch 1: 211977batch [10:44, 331.08batch/s]
# Epoch 1: 212011batch [10:45, 333.61batch/s]
# Epoch 1: 212045batch [10:45, 331.33batch/s]
# Epoch 1: 212079batch [10:45, 327.85batch/s]
# Epoch 1: 212112batch [10:45, 324.68batch/s]
# Epoch 1: 212148batch [10:45, 332.08batch/s]
# Epoch 1: 212185batch [10:45, 343.17batch/s]
# Epoch 1: 212220batch [10:45, 339.19batch/s]
# Epoch 1: 212254batch [10:45, 338.43batch/s]
# Epoch 1: 212288batch [10:45, 333.93batch/s]
# Epoch 1: 212322batch [10:45, 328.96batch/s]
# Epoch 1: 212355batch [10:46, 325.96batch/s]
# Epoch 1: 212388batch [10:46, 325.25batch/s]
# Epoch 1: 212423batch [10:46, 330.56batch/s]
# Epoch 1: 212459batch [10:46, 337.21batch/s]
# Epoch 1: 212493batch [10:46, 333.13batch/s]
# Epoch 1: 212527batch [10:46, 329.35batch/s]
# Epoch 1: 212560batch [10:46, 326.69batch/s]
# Epoch 1: 212596batch [10:46, 335.44batch/s]
# Epoch 1: 212630batch [10:46, 286.91batch/s]
# Epoch 1: 212667batch [10:47, 306.37batch/s]
# Epoch 1: 212700batch [10:47, 311.95batch/s]
# Epoch 1: 212733batch [10:47, 316.11batch/s]
# Epoch 1: 212766batch [10:47, 318.25batch/s]
# Epoch 1: 212801batch [10:47, 327.39batch/s]
# Epoch 1: 212839batch [10:47, 340.73batch/s]
# Epoch 1: 212876batch [10:47, 348.28batch/s]
# Epoch 1: 212912batch [10:47, 334.61batch/s]
# Epoch 1: 212946batch [10:47, 332.35batch/s]
# Epoch 1: 212980batch [10:48, 318.80batch/s]
# Epoch 1: 213013batch [10:48, 306.19batch/s]
# Epoch 1: 213045batch [10:48, 309.15batch/s]
# Epoch 1: 213078batch [10:48, 314.15batch/s]
# Epoch 1: 213114batch [10:48, 325.45batch/s]
# Epoch 1: 213148batch [10:48, 328.71batch/s]
# Epoch 1: 213186batch [10:48, 342.69batch/s]
# Epoch 1: 213221batch [10:48, 335.96batch/s]
# Epoch 1: 213255batch [10:48, 334.22batch/s]
# Epoch 1: 213292batch [10:48, 342.64batch/s]
# Epoch 1: 213327batch [10:49, 335.68batch/s]
# Epoch 1: 213361batch [10:49, 302.08batch/s]
# Epoch 1: 213392batch [10:49, 295.85batch/s]
# Epoch 1: 213425batch [10:49, 304.34batch/s]
# Epoch 1: 213458batch [10:49, 308.93batch/s]
# Epoch 1: 213491batch [10:49, 313.14batch/s]
# Epoch 1: 213524batch [10:49, 316.66batch/s]
# Epoch 1: 213557batch [10:49, 318.06batch/s]
# Epoch 1: 213590batch [10:49, 319.16batch/s]
# Epoch 1: 213625batch [10:50, 327.01batch/s]
# Epoch 1: 213658batch [10:50, 324.08batch/s]
# Epoch 1: 213691batch [10:50, 323.91batch/s]
# Epoch 1: 213724batch [10:50, 322.85batch/s]
# Epoch 1: 213762batch [10:50, 338.66batch/s]
# Epoch 1: 213796batch [10:50, 331.71batch/s]
# Epoch 1: 213830batch [10:50, 328.38batch/s]
# Epoch 1: 213863batch [10:50, 327.87batch/s]
# Epoch 1: 213899batch [10:50, 336.69batch/s]
# Epoch 1: 213936batch [10:50, 343.46batch/s]
# Epoch 1: 213971batch [10:51, 339.39batch/s]
# Epoch 1: 214005batch [10:51, 336.62batch/s]
# Epoch 1: 214043batch [10:51, 349.32batch/s]
# Epoch 1: 214078batch [10:51, 344.44batch/s]
# Epoch 1: 214113batch [10:51, 343.05batch/s]
# Epoch 1: 214148batch [10:51, 312.92batch/s]
# Epoch 1: 214180batch [10:51, 311.22batch/s]
# Epoch 1: 214212batch [10:51, 306.01batch/s]
# Epoch 1: 214244batch [10:51, 308.76batch/s]
# Epoch 1: 214281batch [10:52, 323.69batch/s]
# Epoch 1: 214314batch [10:52, 322.72batch/s]
# Epoch 1: 214347batch [10:52, 322.96batch/s]
# Epoch 1: 214384batch [10:52, 335.70batch/s]
# Epoch 1: 214418batch [10:52, 330.18batch/s]
# Epoch 1: 214452batch [10:52, 329.87batch/s]
# Epoch 1: 214486batch [10:52, 327.96batch/s]
# Epoch 1: 214520batch [10:52, 329.46batch/s]
# Epoch 1: 214554batch [10:52, 330.61batch/s]
# Epoch 1: 214588batch [10:52, 328.55batch/s]
# Epoch 1: 214623batch [10:53, 334.82batch/s]
# Epoch 1: 214658batch [10:53, 336.32batch/s]
# Epoch 1: 214692batch [10:53, 332.51batch/s]
# Epoch 1: 214727batch [10:53, 336.65batch/s]
# Epoch 1: 214761batch [10:53, 334.67batch/s]
# Epoch 1: 214799batch [10:53, 344.97batch/s]
# Epoch 1: 214834batch [10:53, 343.42batch/s]
# Epoch 1: 214872batch [10:53, 352.11batch/s]
# Epoch 1: 214908batch [10:53, 343.51batch/s]
# Epoch 1: 214943batch [10:53, 335.20batch/s]
# Epoch 1: 214977batch [10:54, 304.82batch/s]
# Epoch 1: 215008batch [10:54, 303.52batch/s]
# Epoch 1: 215042batch [10:54, 311.33batch/s]
# Epoch 1: 215075batch [10:54, 313.94batch/s]
# Epoch 1: 215112batch [10:54, 329.00batch/s]
# Epoch 1: 215146batch [10:54, 329.50batch/s]
# Epoch 1: 215180batch [10:54, 330.63batch/s]
# Epoch 1: 215214batch [10:54, 327.56batch/s]
# Epoch 1: 215247batch [10:54, 326.56batch/s]
# Epoch 1: 215280batch [10:55, 324.37batch/s]
# Epoch 1: 215313batch [10:55, 324.12batch/s]
# Epoch 1: 215346batch [10:55, 323.00batch/s]
# Epoch 1: 215385batch [10:55, 341.67batch/s]
# Epoch 1: 215420batch [10:55, 335.23batch/s]
# Epoch 1: 215454batch [10:55, 332.75batch/s]
# Epoch 1: 215492batch [10:55, 345.50batch/s]
# Epoch 1: 215530batch [10:55, 353.54batch/s]
# Epoch 1: 215566batch [10:55, 347.27batch/s]
# Epoch 1: 215601batch [10:56, 338.23batch/s]
# Epoch 1: 215636batch [10:56, 339.33batch/s]
# Epoch 1: 215670batch [10:56, 337.57batch/s]
# Epoch 1: 215705batch [10:56, 341.19batch/s]
# Epoch 1: 215740batch [10:56, 335.66batch/s]
# Epoch 1: 215774batch [10:56, 297.40batch/s]
# Epoch 1: 215805batch [10:56, 296.20batch/s]
# Epoch 1: 215836batch [10:56, 298.26batch/s]
# Epoch 1: 215868batch [10:56, 300.98batch/s]
# Epoch 1: 215900batch [10:56, 306.37batch/s]
# Epoch 1: 215935batch [10:57, 316.61batch/s]
# Epoch 1: 215969batch [10:57, 321.34batch/s]
# Epoch 1: 216002batch [10:57, 321.06batch/s]
# Epoch 1: 216039batch [10:57, 334.40batch/s]
# Epoch 1: 216073batch [10:57, 334.08batch/s]
# Epoch 1: 216107batch [10:57, 333.86batch/s]
# Epoch 1: 216141batch [10:57, 333.70batch/s]
# Epoch 1: 216175batch [10:57, 330.68batch/s]
# Epoch 1: 216209batch [10:57, 329.54batch/s]
# Epoch 1: 216244batch [10:57, 332.62batch/s]
# Epoch 1: 216280batch [10:58, 337.68batch/s]
# Epoch 1: 216319batch [10:58, 350.97batch/s]
# Epoch 1: 216355batch [10:58, 346.49batch/s]
# Epoch 1: 216393batch [10:58, 356.27batch/s]
# Epoch 1: 216429batch [10:58, 348.15batch/s]
# Epoch 1: 216465batch [10:58, 350.39batch/s]
# Epoch 1: 216504batch [10:58, 359.32batch/s]
# Epoch 1: 216541batch [10:58, 362.45batch/s]
# Epoch 1: 216579batch [10:58, 365.47batch/s]
# Epoch 1: 216616batch [10:59, 351.24batch/s]
# Epoch 1: 216652batch [10:59, 300.87batch/s]
# Epoch 1: 216684batch [10:59, 304.25batch/s]
# Epoch 1: 216716batch [10:59, 301.08batch/s]
# Epoch 1: 216748batch [10:59, 304.93batch/s]
# Epoch 1: 216781batch [10:59, 310.87batch/s]
# Epoch 1: 216816batch [10:59, 320.70batch/s]
# Epoch 1: 216853batch [10:59, 334.09batch/s]
# Epoch 1: 216887batch [10:59, 333.17batch/s]
# Epoch 1: 216921batch [11:00, 329.06batch/s]
# Epoch 1: 216955batch [11:00, 329.08batch/s]
# Epoch 1: 216989batch [11:00, 331.55batch/s]
# Epoch 1: 217025batch [11:00, 339.90batch/s]
# Epoch 1: 217060batch [11:00, 334.97batch/s]
# Epoch 1: 217094batch [11:00, 330.65batch/s]
# Epoch 1: 217132batch [11:00, 343.99batch/s]
# Epoch 1: 217170batch [11:00, 351.45batch/s]
# Epoch 1: 217208batch [11:00, 359.82batch/s]
# Epoch 1: 217245batch [11:00, 354.45batch/s]
# Epoch 1: 217281batch [11:01, 350.95batch/s]
# Epoch 1: 217317batch [11:01, 350.53batch/s]
# Epoch 1: 217353batch [11:01, 347.21batch/s]
# Epoch 1: 217388batch [11:01, 341.08batch/s]
# Epoch 1: 217423batch [11:01, 334.64batch/s]
# Epoch 1: 217457batch [11:01, 318.57batch/s]
# Epoch 1: 217490batch [11:01, 293.82batch/s]
# Epoch 1: 217522batch [11:01, 300.82batch/s]
# Epoch 1: 217555batch [11:01, 306.35batch/s]
# Epoch 1: 217588batch [11:02, 312.83batch/s]
# Epoch 1: 217625batch [11:02, 328.28batch/s]
# Epoch 1: 217660batch [11:02, 333.61batch/s]
# Epoch 1: 217694batch [11:02, 329.69batch/s]
# Epoch 1: 217728batch [11:02, 327.92batch/s]
# Epoch 1: 217764batch [11:02, 337.24batch/s]
# Epoch 1: 217798batch [11:02, 332.21batch/s]
# Epoch 1: 217833batch [11:02, 336.42batch/s]
# Epoch 1: 217867batch [11:02, 332.58batch/s]
# Epoch 1: 217901batch [11:02, 330.23batch/s]
# Epoch 1: 217935batch [11:03, 332.11batch/s]
# Epoch 1: 217974batch [11:03, 347.07batch/s]
# Epoch 1: 218011batch [11:03, 352.66batch/s]
# Epoch 1: 218047batch [11:03, 343.66batch/s]
# Epoch 1: 218082batch [11:03, 337.66batch/s]
# Epoch 1: 218116batch [11:03, 331.64batch/s]
# Epoch 1: 218153batch [11:03, 341.98batch/s]
# Epoch 1: 218191batch [11:03, 352.01batch/s]
# Epoch 1: 218227batch [11:03, 343.29batch/s]
# Epoch 1: 218264batch [11:04, 349.99batch/s]
# Epoch 1: 218301batch [11:04, 353.58batch/s]
# Epoch 1: 218337batch [11:04, 353.39batch/s]
# Epoch 1: 218373batch [11:04, 339.89batch/s]
# Epoch 1: 218409batch [11:04, 342.71batch/s]
# Epoch 1: 218446batch [11:04, 348.57batch/s]
# Epoch 1: 218481batch [11:04, 339.13batch/s]
# Epoch 1: 218516batch [11:04, 299.77batch/s]
# Epoch 1: 218547batch [11:04, 298.45batch/s]
# Epoch 1: 218580batch [11:05, 305.36batch/s]
# Epoch 1: 218613batch [11:05, 310.50batch/s]
# Epoch 1: 218646batch [11:05, 314.24batch/s]
# Epoch 1: 218679batch [11:05, 316.05batch/s]
# Epoch 1: 218715batch [11:05, 326.86batch/s]
# Epoch 1: 218748batch [11:05, 325.83batch/s]
# Epoch 1: 218781batch [11:05, 327.05batch/s]
# Epoch 1: 218819batch [11:05, 339.65batch/s]
# Epoch 1: 218854batch [11:05, 341.69batch/s]
# Epoch 1: 218889batch [11:05, 338.15batch/s]
# Epoch 1: 218926batch [11:06, 344.46batch/s]
# Epoch 1: 218961batch [11:06, 339.12batch/s]
# Epoch 1: 218995batch [11:06, 333.55batch/s]
# Epoch 1: 219031batch [11:06, 339.26batch/s]
# Epoch 1: 219070batch [11:06, 352.01batch/s]
# Epoch 1: 219106batch [11:06, 349.23batch/s]
# Epoch 1: 219144batch [11:06, 357.18batch/s]
# Epoch 1: 219180batch [11:06, 349.79batch/s]
# Epoch 1: 219216batch [11:06, 303.43batch/s]
# Epoch 1: 219248batch [11:07, 297.64batch/s]
# Epoch 1: 219279batch [11:07, 257.51batch/s]
# Epoch 1: 219312batch [11:07, 274.66batch/s]
# Epoch 1: 219345batch [11:07, 287.53batch/s]
# Epoch 1: 219383batch [11:07, 311.60batch/s]
# Epoch 1: 219419batch [11:07, 323.23batch/s]
# Epoch 1: 219454batch [11:07, 329.87batch/s]
# Epoch 1: 219488batch [11:07, 330.88batch/s]
# Epoch 1: 219522batch [11:07, 327.82batch/s]
# Epoch 1: 219556batch [11:08, 325.69batch/s]
# Epoch 1: 219589batch [11:08, 326.93batch/s]
# Epoch 1: 219624batch [11:08, 333.35batch/s]
# Epoch 1: 219658batch [11:08, 331.41batch/s]
# Epoch 1: 219693batch [11:08, 334.90batch/s]
# Epoch 1: 219727batch [11:08, 335.41batch/s]
# Epoch 1: 219761batch [11:08, 331.47batch/s]
# Epoch 1: 219798batch [11:08, 339.85batch/s]
# Epoch 1: 219836batch [11:08, 351.54batch/s]
# Epoch 1: 219872batch [11:08, 340.94batch/s]
# Epoch 1: 219907batch [11:09, 340.60batch/s]
# Epoch 1: 219943batch [11:09, 344.24batch/s]
# Epoch 1: 219978batch [11:09, 339.97batch/s]
# Epoch 1: 220013batch [11:09, 309.58batch/s]
# Epoch 1: 220045batch [11:09, 297.03batch/s]
# Epoch 1: 220082batch [11:09, 315.05batch/s]
# Epoch 1: 220117batch [11:09, 322.95batch/s]
# Epoch 1: 220154batch [11:09, 335.66batch/s]
# Epoch 1: 220190batch [11:09, 340.49batch/s]
# Epoch 1: 220225batch [11:10, 339.31batch/s]
# Epoch 1: 220260batch [11:10, 333.73batch/s]
# Epoch 1: 220294batch [11:10, 329.50batch/s]
# Epoch 1: 220332batch [11:10, 344.03batch/s]
# Epoch 1: 220367batch [11:10, 341.79batch/s]
# Epoch 1: 220404batch [11:10, 348.99batch/s]
# Epoch 1: 220439batch [11:10, 341.28batch/s]
# Epoch 1: 220476batch [11:10, 349.62batch/s]
# Epoch 1: 220512batch [11:10, 350.26batch/s]
# Epoch 1: 220548batch [11:10, 341.10batch/s]
# Epoch 1: 220584batch [11:11, 344.92batch/s]
# Epoch 1: 220619batch [11:11, 340.32batch/s]
# Epoch 1: 220654batch [11:11, 334.40batch/s]
# Epoch 1: 220688batch [11:11, 333.14batch/s]
# Epoch 1: 220722batch [11:11, 332.24batch/s]
# Epoch 1: 220756batch [11:11, 328.76batch/s]
# Epoch 1: 220789batch [11:11, 288.88batch/s]
# Epoch 1: 220827batch [11:11, 311.51batch/s]
# Epoch 1: 220864batch [11:11, 327.58batch/s]
# Epoch 1: 220898batch [11:12, 328.01batch/s]
# Epoch 1: 220936batch [11:12, 340.89batch/s]
# Epoch 1: 220973batch [11:12, 348.28batch/s]
# Epoch 1: 221010batch [11:12, 353.57batch/s]
# Epoch 1: 221046batch [11:12, 346.32batch/s]
# Epoch 1: 221081batch [11:12, 340.94batch/s]
# Epoch 1: 221117batch [11:12, 346.45batch/s]
# Epoch 1: 221152batch [11:12, 344.47batch/s]
# Epoch 1: 221187batch [11:12, 340.11batch/s]
# Epoch 1: 221222batch [11:12, 335.18batch/s]
# Epoch 1: 221256batch [11:13, 330.84batch/s]
# Epoch 1: 221293batch [11:13, 341.16batch/s]
# Epoch 1: 221331batch [11:13, 350.44batch/s]
# Epoch 1: 221367batch [11:13, 342.20batch/s]
# Epoch 1: 221403batch [11:13, 345.56batch/s]
# Epoch 1: 221438batch [11:13, 345.85batch/s]
# Epoch 1: 221473batch [11:13, 340.09batch/s]
# Epoch 1: 221512batch [11:13, 352.55batch/s]
# Epoch 1: 221548batch [11:13, 348.88batch/s]
# Epoch 1: 221583batch [11:14, 338.99batch/s]
# Epoch 1: 221617batch [11:14, 338.22batch/s]
# Epoch 1: 221655batch [11:14, 349.34batch/s]
# Epoch 1: 221690batch [11:14, 342.52batch/s]
# Epoch 1: 221725batch [11:14, 335.90batch/s]
# Epoch 1: 221763batch [11:14, 346.61batch/s]
# Epoch 1: 221798batch [11:14, 343.60batch/s]
# Epoch 1: 221833batch [11:14, 317.74batch/s]
# Epoch 1: 221866batch [11:14, 302.83batch/s]
# Epoch 1: 221897batch [11:15, 299.10batch/s]
# Epoch 1: 221931batch [11:15, 309.52batch/s]
# Epoch 1: 221964batch [11:15, 314.88batch/s]
# Epoch 1: 222001batch [11:15, 329.74batch/s]
# Epoch 1: 222039batch [11:15, 343.33batch/s]
# Epoch 1: 222074batch [11:15, 344.27batch/s]
# Epoch 1: 222113batch [11:15, 355.62batch/s]
# Epoch 1: 222149batch [11:15, 347.53batch/s]
# Epoch 1: 222184batch [11:15, 345.24batch/s]
# Epoch 1: 222222batch [11:15, 355.37batch/s]
# Epoch 1: 222258batch [11:16, 347.53batch/s]
# Epoch 1: 222293batch [11:16, 340.55batch/s]
# Epoch 1: 222328batch [11:16, 336.85batch/s]
# Epoch 1: 222365batch [11:16, 345.93batch/s]
# Epoch 1: 222404batch [11:16, 356.69batch/s]
# Epoch 1: 222440batch [11:16, 352.14batch/s]
# Epoch 1: 222476batch [11:16, 343.42batch/s]
# Epoch 1: 222511batch [11:16, 341.38batch/s]
# Epoch 1: 222546batch [11:16, 342.45batch/s]
# Epoch 1: 222581batch [11:17, 326.58batch/s]
# Epoch 1: 222614batch [11:17, 291.45batch/s]
# Epoch 1: 222648batch [11:17, 302.61batch/s]
# Epoch 1: 222681batch [11:17, 307.57batch/s]
# Epoch 1: 222715batch [11:17, 314.86batch/s]
# Epoch 1: 222749batch [11:17, 319.28batch/s]
# Epoch 1: 222782batch [11:17, 319.60batch/s]
# Epoch 1: 222817batch [11:17, 327.44batch/s]
# Epoch 1: 222852batch [11:17, 333.04batch/s]
# Epoch 1: 222886batch [11:17, 331.20batch/s]
# Epoch 1: 222920batch [11:18, 331.83batch/s]
# Epoch 1: 222954batch [11:18, 331.37batch/s]
# Epoch 1: 222988batch [11:18, 329.56batch/s]
# Epoch 1: 223025batch [11:18, 340.21batch/s]
# Epoch 1: 223064batch [11:18, 351.76batch/s]
# Epoch 1: 223100batch [11:18, 351.09batch/s]
# Epoch 1: 223136batch [11:18, 346.57batch/s]
# Epoch 1: 223171batch [11:18, 345.56batch/s]
# Epoch 1: 223208batch [11:18, 351.69batch/s]
# Epoch 1: 223244batch [11:18, 344.01batch/s]
# Epoch 1: 223279batch [11:19, 338.84batch/s]
# Epoch 1: 223313batch [11:19, 335.78batch/s]
# Epoch 1: 223351batch [11:19, 346.53batch/s]
# Epoch 1: 223386batch [11:19, 302.32batch/s]
# Epoch 1: 223418batch [11:19, 300.11batch/s]
# Epoch 1: 223451batch [11:19, 307.41batch/s]
# Epoch 1: 223488batch [11:19, 322.15batch/s]
# Epoch 1: 223522batch [11:19, 327.20batch/s]
# Epoch 1: 223556batch [11:19, 330.89batch/s]
# Epoch 1: 223593batch [11:20, 342.28batch/s]
# Epoch 1: 223630batch [11:20, 349.40batch/s]
# Epoch 1: 223666batch [11:20, 341.45batch/s]
# Epoch 1: 223702batch [11:20, 344.83batch/s]
# Epoch 1: 223737batch [11:20, 337.48batch/s]
# Epoch 1: 223771batch [11:20, 336.26batch/s]
# Epoch 1: 223805batch [11:20, 330.61batch/s]
# Epoch 1: 223841batch [11:20, 338.14batch/s]
# Epoch 1: 223875batch [11:20, 334.78batch/s]
# Epoch 1: 223912batch [11:21, 345.06batch/s]
# Epoch 1: 223947batch [11:21, 340.50batch/s]
# Epoch 1: 223982batch [11:21, 334.06batch/s]
# Epoch 1: 224016batch [11:21, 333.85batch/s]
# Epoch 1: 224050batch [11:21, 332.74batch/s]
# Epoch 1: 224084batch [11:21, 330.99batch/s]
# Epoch 1: 224122batch [11:21, 343.29batch/s]
# Epoch 1: 224157batch [11:21, 341.26batch/s]
# Epoch 1: 224192batch [11:21, 340.82batch/s]
# Epoch 1: 224228batch [11:21, 345.92batch/s]
# Epoch 1: 224263batch [11:22, 305.68batch/s]
# Epoch 1: 224295batch [11:22, 299.81batch/s]
# Epoch 1: 224326batch [11:22, 298.32batch/s]
# Epoch 1: 224361batch [11:22, 310.93batch/s]
# Epoch 1: 224395batch [11:22, 317.35batch/s]
# Epoch 1: 224429batch [11:22, 321.08batch/s]
# Epoch 1: 224463batch [11:22, 324.66batch/s]
# Epoch 1: 224496batch [11:22, 321.44batch/s]
# Epochs: 100%|████████████████████████████████████████████████████████████████████████| 1/1 [11:23<00:00, 683.74s/epoch]
# Epoch [1/1], Loss: 0.0013

# %% [markdown]
# ## Evaluation Loop

# %%
from torch.nn import MSELoss


train_set = torch.tensor(train_df.values[:,:].astype(np.float32), dtype=torch.float32)
val_set = torch.tensor(val_df.values[:,:].astype(np.float32), dtype=torch.float32)
test_set = torch.tensor(val_df.values[:,:].astype(np.float32), dtype=torch.float32)

points_to_predict = val_set.shape[1]

# Autoregressive prediction function
def autoregressive_predict(model, input_maxtrix, prediction_length=points_to_predict):
    """
    Perform autoregressive prediction using the learned model.
    
    Args:
    - model: The trained PyTorch model.
    - input_maxtrix: A matrix of initial time steps (e.g., shape (963, window_length)).
    - prediction_length: The length of the future trajectory to predict.
    
    Returns:
    - output_matrix: A tensor of the predicted future trajectory of the same length as `prediction_length`.
    """
    model.eval()  # Set model to evaluation mode
    output_matrix = torch.empty(input_maxtrix.shape[0],0)
    current_input = input_maxtrix
    
    with torch.no_grad():  # No need to calculate gradients for prediction
        for idx in range(prediction_length):
            # Predict the next time step
            next_pred = model(current_input)
            
            # Concatenating the new column along dimension 1 (columns)
            output_matrix = torch.cat((output_matrix, next_pred), dim=1)
            
            # Use the predicted value as part of the next input
            current_input = torch.cat((current_input[:, 1:],next_pred),dim=1)
    
    return output_matrix


initial_input = train_set[:, -window_length:]  #use the last window of training set as initial input
full_trajectories = autoregressive_predict(model, initial_input)


# Calculate MSE between predicted trajectories and actual validation trajectories using torch
mse_loss = MSELoss()

# Compute MSE
mse = mse_loss(full_trajectories, val_set)

# Print MSE
print(f'Autoregressive Validation MSE (using torch): {mse.item():.4f}')
# Out:
# Autoregressive Validation MSE (using torch): 0.0018

# %% [markdown]
# ## Plot it out to see what is like

# %%
# Perform autoregressive predictions for one row in the validation set
# We can pick a specific row (e.g., row 0) to visualize
row_idx = 0  # You can change this to visualize predictions for different rows
initial_input = val_set[row_idx, :window_length].unsqueeze(0)

# Predict future trajectory of length 100
predicted_trajectory = autoregressive_predict(model, initial_input)

# Get the actual trajectory for comparison
actual_trajectory = val_set[row_idx].numpy()

# Plot the actual vs predicted trajectory
plt.figure(figsize=(10, 6))
plt.plot(range(len(actual_trajectory)), actual_trajectory, label="Actual Trajectory", color='blue', marker='o')
plt.plot(range(len(actual_trajectory)), predicted_trajectory.squeeze().numpy(), label="Predicted Trajectory", color='red', linestyle='--', marker='x')
plt.title(f"Actual vs Predicted Trajectory (Row {row_idx})")
plt.xlabel("Time Step")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Generate and save plots for the first three trajectory instances
for row_idx in range(3):  # Loop over the first three instances
    # Get the initial input for the selected row
    initial_input = val_set[row_idx, :window_length].unsqueeze(0)
    
    # Perform autoregressive prediction
    predicted_trajectory = autoregressive_predict(model, initial_input)
    
    # Get the actual trajectory for comparison
    actual_trajectory = val_set[row_idx].numpy()
    
    # Create a plot with the specified figsize and dpi
    plt.figure(figsize=(4, 4), dpi=200)
    plt.plot(range(len(actual_trajectory)), actual_trajectory, label="Actual Trajectory", color='blue', marker='o')
    plt.plot(range(len(actual_trajectory)), predicted_trajectory.squeeze().numpy(), label="Predicted Trajectory", color='red', linestyle='--', marker='x')
    plt.title(f"Actual vs Predicted Trajectory (Row {row_idx})")
    plt.xlabel("Time Step")
    plt.ylabel("Value")
    plt.legend()
    plt.grid(True)
    
    # Save the figure as a PNG file with a unique filename
    plt.savefig(f"trajectory_prediction_row_{row_idx}.png", format='png')
    plt.close()  # Close the figure to free up memory

# %%
# Generate predictions for all the validation dataset
initial_input = train_set[:, -window_length:]
val_predictions_tensor = autoregressive_predict(model, initial_input)

# Generate predictions for all the test dataset
initial_input = val_predictions_tensor[:, -window_length:]
test_predictions_tensor = autoregressive_predict(model, initial_input)


# Print their shapes
print(f'Validation Predictions Tensor Shape: {val_predictions_tensor.shape}')
print(f'Test Predictions Tensor Shape: {test_predictions_tensor.shape}')
# Out:
# Validation Predictions Tensor Shape: torch.Size([963, 1500])
# Test Predictions Tensor Shape: torch.Size([963, 1500])

# %%
def generate_submissions_v4(pred_val_tensor, pred_test_tensor, original_val_path, original_test_path):
    # Read the original validation and testing datasets
    original_val_df = pd.read_csv(original_val_path)
    original_test_df = pd.read_csv(original_test_path)

    # Ensure the shape of pred_val_tensor and pred_test_tensor is correct
    assert pred_val_tensor.shape[0] * pred_val_tensor.shape[1] == original_val_df.shape[0] * (original_val_df.shape[1] - 1)
    assert pred_test_tensor.shape[0] * pred_test_tensor.shape[1] == original_test_df.shape[0] * (original_test_df.shape[1] - 1)

    # Create empty lists to store ids and values
    ids = []
    values = []

    # Process validation set
    for col_idx, col in enumerate(original_val_df.columns[1:]):  # Skip the 'ids' column
        for row_idx, _ in enumerate(original_val_df[col]):
            ids.append(str(f"{col}_traffic_val_{row_idx}"))
            values.append(float(pred_val_tensor[row_idx, col_idx]))

    # Process testing set
    for col_idx, col in enumerate(original_test_df.columns[1:]):  # Skip the 'ids' column
        for row_idx, _ in enumerate(original_test_df[col]):
            ids.append(str(f"{col}_traffic_test_{row_idx}"))
            values.append(float(pred_test_tensor[row_idx, col_idx]))

    # Create the submissions dataframe
    submissions_df = pd.DataFrame({
        "ids": ids,
        "value": values
    })
    
    # Impute any null values
    submissions_df.fillna(100, inplace=True)

    # Assert the shape of the dataframe
    assert submissions_df.shape[1] == 2
    assert submissions_df.shape[0] == (original_val_df.shape[0] * (original_val_df.shape[1] - 1)) + (original_test_df.shape[0] * (original_test_df.shape[1] - 1))
    assert "ids" in submissions_df.columns
    assert "value" in submissions_df.columns

    # Save to CSV
    submissions_df.to_csv('submissions_v3.csv', index=False)

# Call the function
generate_submissions_v4(val_predictions_tensor, test_predictions_tensor, 'val.csv', 'test.csv')
